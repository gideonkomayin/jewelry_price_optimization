# %% [markdown]
# ## 1. Project Title: Machine Learning for Jewelry Price Optimization
#
# This project aims to successfully predict the prices of jewelry pieces. This will allow the jewelry company to reduce its dependence on gemologists and expensive jewelry appraisal experts.

# %% [markdown]
# ## 2. Methodology
#
# This project will be carried out using the CRISP-DM (Cross Industry Standard Process for Data Mining) methodology. This is one of the more popular data science methodologies and is characterized by six important phases, which are as follows:
#
# 1. Business Understanding,
# 2. Data Understanding,
# 3. Data Preparation,
# 4. Data Modellling,
# 5. Model Evaluation and
# 6. Model Deployment
#
# It should be noted that thease phases are usually recurrent in nature (i.e. some phases may be repeated). As such, they do not necessarily follow a linear progression.

# %% [markdown]
# ## 3. Tools
#
# The tools of use for this project include:
# 1. Pandas
# 2. Numpy
# 3. Matplotlib & Seaborn
# 4. Sci-kit Learn
#
# 3.1 Pamdas & Numpy
# Pandas is a Python library built upon the Numpy library. The idea behind Pandas is to be able to operate on text data, where Numpy is best suited for numerical operations, irrespective of the fact that it can represent text to some degree.
#
# 3.2 Matplotlib & Seaborn
# Matplotlib & Seaborn are Python libraries for data visualization. Other alternatives include Bokeh and Plotly.
#
# 3.3 Sci-kit Learn
# Sci-kit Learn is a Python library which is used extensively for machine learning. It has a simple API centered arund two maintypes of objects:
#
# * Transformers and
# * Estimators
#
# Transformers are used to transform data fron one form to another, while estimators arte used to learn from data and generate some kind of prediction. Sci-kit Learn is perhaps the most popular ML library due to facts:
#
# * that has a very simple API,
# * it is relatively easy to get started with, and
# * it has a wide variety of use cases.

# %% [markdown]
# ## Project Implementation vis CRISP-DM

# %% [markdown]
# #### 01. Business Understanding

# %% [markdown]
# ##### Gemineye Emporium is an expanding jewelry dealer. The firm has recently begun a new wave of expansion across the country. While this should be good for business. it also comes with increased costs and the need for increased operational efficiency.
#
# One such area is the need to accurately price their jewelry products. At present, their jewelry items are being priced by gemologists and appraisal experts. However, this process can be quite a lengthy one, not to mention expensive, as most gemologists are well-sought and expensive to call upon. Gemineye would love to explore the use of machine learning for predicting the optimal prices at whihc their jewelry should be sold. Utilizing ML for this task would allow the company:
#
# * improve the speed and scalability of their pricing, and
# * cut down on the costs of hiring gem experts.

# %% [markdown]
# #### 02. Data Understanding
#
# With the Business Understaing out of the way, the next step is to understand the data to be obtained and used for the task. This will involve the process of Exploratory Data Analysis (EDA).

# %% [markdown]
# #### EDA is the process of sifting through data with the goal of extracting insights. These insights allow a better understanding of the available data and what can be done with it.
# #### They can also be used for guided preparation of the dataset in the appropriate manner. Just like regiular analysis, EDA begins with a set of questions and /or hypotheses. The EDA process will then prove or disprove these hypotheses, and hopefully, reveal other points of inquiry along the way.
#
# #### The required libraries and packah=ges are imported first. The EDA process is carried out here as shown below. The high-level steps to follow are:
#
# * 1. Import the required libraries
#   2. Load in the dataset
#   3. Analyze and observe its properties.
#      * Missing data
#      * Outliers
#      * Inconsistent values
#      * Low categorical cardinality
#      * Data imbalance
#      * Feature correlations
# * 4. Report on these properties and how they might affect our final solution.

# %%
# !pip install catboost
# Import libraries
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt

# Set visualization theme
sns.set()
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.11/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from catboost) (3.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.11/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.11/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.11/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.11/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.11/dist-packages (from catboost) (1.17.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas>=0.24->catboost) (2025.1)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->catboost) (3.2.1)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.11/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp311-cp311-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 7.1 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
# Import the dataset
data = pd.read_csv(r"/content/sample_data/Jewelry_Dataset.csv")

data.columns = [
    "Order_Datetime",
    "Order_ID",
    "Product_Id",
    "SKU_Quantity",
    "Category_ID",
    "Category",
    "Brand_ID",
    "Price_USD",
    "User_ID",
    "Target_Gender",
    "Main_Color",
    "Main_Metal",
    "Main_Gem",

]

# %%
# Peek at the data
data.head()
# Out:
#             Order_Datetime             Order_ID           Product_Id  \
# 0  2018-12-01 17:38:31 UTC  1924899396621697920  1806829193678291446
# 1  2018-12-02 13:53:42 UTC  1925511016616034733  1842214461889315556
# 2  2018-12-02 17:44:02 UTC  1925626951238681511  1835566849434059453
# 3  2018-12-02 21:30:19 UTC  1925740842841014667  1873936840742928865
# 4  2018-12-02 22:09:34 UTC  1925760595336888995  1835566854827934449
#
#    SKU_Quantity   Category_ID          Category  Brand_ID  Price_USD  \
# 0             1  1.806829e+18               NaN       NaN     212.14
# 1             1  1.806829e+18   jewelry.pendant       1.0      54.66
# 2             1  1.806829e+18   jewelry.pendant       0.0      88.90
# 3             1  1.806829e+18  jewelry.necklace       0.0     417.67
# 4             1  1.806829e+18   jewelry.earring       1.0     102.27
#
#         User_ID Target_Gender Main_Color Main_Metal  Main_Gem
# 0  1.515916e+18           NaN     yellow       gold       NaN
# 1  1.515916e+18             f      white       gold  sapphire
# 2  1.515916e+18             f        red       gold   diamond
# 3  1.515916e+18           NaN        red       gold  amethyst
# 4  1.515916e+18           NaN        red       gold       NaN

# %%
# Check for missing values
data.isnull().sum()
# Out:
# Order_Datetime        0
# Order_ID              0
# Product_Id            0
# SKU_Quantity          0
# Category_ID        5352
# Category           9933
# Brand_ID           4785
# Price_USD          5352
# User_ID            5352
# Target_Gender     48167
# Main_Color         7660
# Main_Metal         5462
# Main_Gem          34058
# dtype: int64

# %% [markdown]
# Observation: The above showed there were alot of missing values.

# %%
#Data shape
data.shape
# Out:
# (95910, 13)

# %% [markdown]
# Observation: 50% of data in "Target_Gender" and about 36% of data in "Main_Gem" columns were missing.

# %%
# Feature cardinality (i.e to identify the number of unique values that a column or feature can take)
data.nunique()
# Out:
# Order_Datetime    74504
# Order_ID          74759
# Product_Id         9613
# SKU_Quantity          1
# Category_ID          25
# Category            218
# Brand_ID           2537
# Price_USD          3166
# User_ID           31079
# Target_Gender         2
# Main_Color            5
# Main_Metal            3
# Main_Gem             30
# dtype: int64

# %% [markdown]
# Observation:
# Only 1 unique value was available for SKU_Quantity, which may not be of much use. Also based on the values, we may deduce that the following are categorical values in nature: Target_Gender, Main_Color, Main_Metal and Main_Gem.
# User_ID will be treated as categorical since it is an identifier and cannot be measured in a continuous form, eventhough it has a large cardinality.
# Price_USD is a numerical value as shown on the dataset.

# %%
# Data description
data.describe()
# Out:
#            Order_ID    Product_Id  SKU_Quantity   Category_ID      Brand_ID  \
# count  9.591000e+04  9.591000e+04       95910.0  9.055800e+04  9.112500e+04
# mean   2.485191e+18  1.815970e+18           1.0  1.805947e+18  8.891036e+16
# std    1.934750e+17  2.136814e+17           0.0  2.083954e+16  3.559651e+17
# min    1.924899e+18  1.313551e+18           1.0  1.313678e+18  0.000000e+00
# 25%    2.379732e+18  1.515966e+18           1.0  1.806829e+18  0.000000e+00
# 50%    2.524282e+18  1.956664e+18           1.0  1.806829e+18  1.000000e+00
# 75%    2.644347e+18  1.956664e+18           1.0  1.806829e+18  1.000000e+00
# max    2.719022e+18  2.541962e+18           1.0  1.806829e+18  1.550613e+18
#
#           Price_USD       User_ID
# count  90558.000000  9.055800e+04
# mean     362.213017  1.512644e+18
# std      444.157665  2.374776e+16
# min        0.990000  1.313554e+18
# 25%      145.620000  1.515916e+18
# 50%      258.770000  1.515916e+18
# 75%      431.370000  1.515916e+18
# max    34448.600000  1.554297e+18

# %% [markdown]
# Observation: Based on the statirtical analysis above, Price_USD seemed to the most important feature we might be working with

# %%
# Data info
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 95910 entries, 0 to 95909
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_Datetime  95910 non-null  object
#  1   Order_ID        95910 non-null  int64
#  2   Product_Id      95910 non-null  int64
#  3   SKU_Quantity    95910 non-null  int64
#  4   Category_ID     90558 non-null  float64
#  5   Category        85977 non-null  object
#  6   Brand_ID        91125 non-null  float64
#  7   Price_USD       90558 non-null  float64
#  8   User_ID         90558 non-null  float64
#  9   Target_Gender   47743 non-null  object
#  10  Main_Color      88250 non-null  object
#  11  Main_Metal      90448 non-null  object
#  12  Main_Gem        61852 non-null  object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 9.5+ MB

# %% [markdown]
# Observation: From the above information, we may have to encode the catogical features identified like Target_Gender, Main_Color, Main_Metal, Main_Gem and Category, since they were represented in text.

# %%
# Duplicate values
num_duplicated = len(data.loc[data.duplicated()])

# %%
print(f"Number of duplicate records:", num_duplicated)
# Out:
# Number of duplicate records: 2589

# %%
# Features with a cardinality of 1 (invariant features)
invariant_features = data.nunique()[data.nunique() == 1].index.tolist()

# %%
invariant_features
# Out:
# ['SKU_Quantity']

# %%
# Check for label distribution
data["Price_USD"].skew()
# Out:
# 18.95906072625981

# %% [markdown]
# Observation: The skew is quite high and positive. This means our Price data is likely going to be strongly right skewed.

# %%
# Price Kurtosis
data["Price_USD"].kurtosis()
# Out:
# 1054.8979068506155

# %% [markdown]
# This indicate a very kurtosis

# %%
# Visualize the price distribution.
plt.figure(figsize = (20, 10))

sns.kdeplot(data = data, x ="Price_USD")

plt.xlabel("Price in U.S Dollars")
plt.ylabel("Price Frequency")

plt.tight_layout()
plt.show(); plt.close()

# %% [markdown]
# Observation: From the above Visuals, this shows that the prices at the peak are relatively very rear.

# %%
# Target gender analysis
data["Target_Gender"].value_counts()
# Out:
# Target_Gender
# f    47379
# m      364
# Name: count, dtype: int64

# %%
data["Target_Gender"].value_counts(normalize = True)
# Out:
# Target_Gender
# f    0.992376
# m    0.007624
# Name: proportion, dtype: float64

# %% [markdown]
# Observation: The female gender significantly out performed the male

# %%
# Visualize target gender
plt.figure(figsize = (12, 8))

sns.countplot(data = data, x = "Target_Gender")

plt.xlabel("Gender")
plt.ylabel("Gender Subpopulation")

plt.show(); plt.close()

# %% [markdown]
# Observation: This is incredibly skewed and in favour of the female. As a business concern, a male tailored jewelry might be advised to be taken into account.

# %%
# Jewelry Category analysis
data["Category"].value_counts()
# Out:
# Category
# jewelry.earring     29051
# jewelry.ring        28300
# jewelry.pendant     13088
# jewelry.bracelet     6188
# 0.00                 4392
#                     ...
# 626.58                  1
# 13.42                   1
# 2.88                    1
# 101.23                  1
# 253.77                  1
# Name: count, Length: 218, dtype: int64

# %% [markdown]
# Observation: Not all values presented made sense. The top values are useful since they were categorized rightly, while the ones beneath do not. It showed corruption in the data.

# %%
data["Category"].unique()
# Out:
# array([nan, 'jewelry.pendant', 'jewelry.necklace', 'jewelry.earring',
#        'jewelry.ring', 'jewelry.brooch', 'jewelry.bracelet',
#        'electronics.clocks', 'jewelry.souvenir', '230.12', '202.36',
#        '1098.03', '321.78', '1128.62', '81.27', '34.25', '582.16',
#        '227.37', '234.22', '150.55', '131.82', '2123.15', '109.45',
#        '49.22', '472.47', '205.38', '2746.44', '51.08', '231.12', '76.97',
#        '3054.73', '184.90', '380.10', '357.49', '15.47', '135.33',
#        '719.75', '93.01', '177.95', 'jewelry.stud', '102.10', '595.75',
#        '469.56', '427.07', '53.62', '77.53', '1469.18', '355.27',
#        '184.89', '154.66', '300.58', '83.73', '271.19', '3294.21',
#        '278.04', '3626.26', '126.03', '283.52', '114.38', '89.04', '8.22',
#        '124.88', '89.73', '171.23', '136.93', '19.04', '158.77', '187.10',
#        '151.92', '1845.89', '87.23', '248.58', '596.48', '208.88',
#        '193.11', '169.84', '1447.68', '45.07', '136.85', '282.05',
#        '61.51', '210.21', '137.12', '147.81', '419.45', '825.27',
#        '300.16', '541.78', '308.74', '766.85', '410.82', '101.23', '2.88',
#        '1356.16', '13.42', '35.21', '134.79', '626.58', '13.70', '108.53',
#        '119.01', '7.40', '4.79', '153.97', '482.47', '427.36', '289.18',
#        '25.48', '1858.49', '21.70', '11.77', '198.89', '17.51', '574.66',
#        '1319.93', '393.05', '358.22', '2282.19', '114.93', '371.23',
#        '63.56', '88.77', '133.70', '117.81', '166.03', '130.41', '195.75',
#        '104.79', '228.59', '1686.93', '65.89', '242.19', '252.47',
#        '210.41', '363.42', '149.04', '157.95', '176.30', '160.96',
#        '316.30', '258.77', '268.36', '838.90', '250.96', '832.01',
#        '312.33', '318.71', '323.60', '205.34', '608.22', '343.84',
#        '598.22', '508.08', '245.67', '338.36', '75.21', '573.81',
#        '691.51', '476.68', '247.68', '286.71', '863.67', '236.58',
#        '644.66', '40.82', '1376.99', '1.23', '621.23', '3454.79', '65.62',
#        '59.73', '571.30', '70.96', '271.26', '958.84', '527.26', '271.16',
#        '284.66', '261.64', '493.01', '35.48', '446.16', '526.41',
#        '2517.08', '331.51', '312.88', '148.63', '451.21', '369.82',
#        '537.40', '231.51', '316.34', '451.10', '283.49', '787.67',
#        '131.92', '495.48', '5.48', '186.03', '484.49', '331.23', '133.85',
#        '323.70', '2635.07', '297.22', '0.00', '259.58', '108.33',
#        '4876.49', '308.08', '190.27', '916.44', '132.53', '1829.37',
#        '2208.90', '75.76', '278.01', '662.30', '253.77'], dtype=object)

# %% [markdown]
# Observation: Aside, the missing value and other categorized features, the rest of the numerical information made no sense. So the best thing to do is to eliminate them. Also, it was discovered that while we were dealing with jewelry we had 'electronics.clocks' appeared here.

# %%
# Extract the autual categories
categories = data["Category"].unique().tolist()
categories = [c for c in categories if isinstance(c, str) and "jewelry" in c]

# %%
categories
# Out:
# ['jewelry.pendant',
#  'jewelry.necklace',
#  'jewelry.earring',
#  'jewelry.ring',
#  'jewelry.brooch',
#  'jewelry.bracelet',
#  'jewelry.souvenir',
#  'jewelry.stud']

# %%
# Pick out authentic data based on categories
real_categories = data.loc[data["Category"].isin(categories)]

# %%
# Checking Percentage of missing values again
100 * data.isnull().sum() / len(data)
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_Id         0.000000
# SKU_Quantity       0.000000
# Category_ID        5.580231
# Category          10.356584
# Brand_ID           4.989052
# Price_USD          5.580231
# User_ID            5.580231
# Target_Gender     50.221041
# Main_Color         7.986654
# Main_Metal         5.694922
# Main_Gem          35.510374
# dtype: float64

# %%
# Checking Percentage of missing values ifrom the authentic data based on categories
100 * real_categories.isnull().sum() / len(real_categories)
# Out:
# Order_Datetime     0.000000
# Order_ID           0.000000
# Product_Id         0.000000
# SKU_Quantity       0.000000
# Category_ID        0.000000
# Category           0.000000
# Brand_ID           4.309081
# Price_USD          0.000000
# User_ID            0.000000
# Target_Gender     44.842029
# Main_Color         2.656044
# Main_Metal         0.110617
# Main_Gem          24.232519
# dtype: float64

# %% [markdown]
# Observation: This shows a better situation as there is now a huge reduction in the missing values. For example the Category, Price_USD and User_ID that were missing earlier had been fixed.This means a large chunk of the corruption that was observed was due to having a feature (Category of the jewelry) corrupted.

# %%
# Visualize Jewelry categories
subdata = real_categories["Category"].value_counts()

jewelry_categories, counts = subdata.index.tolist(), subdata.values.tolist()

plt.figure(figsize = (12, 8))

plt.pie(x = counts, labels = jewelry_categories)

plt.show(); plt.close()

# %% [markdown]
# Observation: From the above pie chart, Jewelry.earing and Jewelry.ring seemed to perform the best as they seemed to perform the best.

# %%
# Category count plot
plt.figure(figsize = (15, 8))

sns.countplot(data = real_categories, x = "Category")

plt.xlabel("Jewelry categories")
plt.ylabel("Category frequency")
plt.show(); plt.close()

# %% [markdown]
# Observation: This count plot shows the frequencies of each jewelry categories and we can observe that both jewelry.earing and jewelry.ring accounts for more than 60% of the jewelry categories that people are patronizing.

# %%
# Jewelry Category by gender
plt.figure(figsize = (15, 8))

sns.countplot(data = real_categories, x = "Category", hue = "Target_Gender")

plt.xlabel("Jewelry categories by gender")
plt.ylabel("Frequency")

plt.show(); plt.close()

# %% [markdown]
# Observation: From the above, it showed almost all the jewelry categories were not been patronized by the male gender, except jewelry.ring category. The business owner could be advised at this point on the need to develop an attractive jewelry targeting the male gender and expect good returns.

# %%
# Gender skew in original data
data["Target_Gender"].value_counts(normalize = True)
# Out:
# Target_Gender
# f    0.992376
# m    0.007624
# Name: proportion, dtype: float64

# %%
# Gender skew in original data
real_categories["Target_Gender"].value_counts(normalize = True)
# Out:
# Target_Gender
# f    0.994434
# m    0.005566
# Name: proportion, dtype: float64

# %%
#Encode Jewelry categories
encoded, category_code = pd.factorize(real_categories["Category"])
real_categories.loc[:, "Category"] = encoded

# %%
#Encode gender
encoded, category_code = pd.factorize(real_categories["Target_Gender"])
real_categories.loc[:, "Target_Gender"] = encoded

# %%
#Encode gems
encoded, category_code = pd.factorize(real_categories["Main_Gem"])
real_categories.loc[:, "Main_Gem"] = encoded

# %%
#Encode color
encoded, category_code = pd.factorize(real_categories["Main_Color"])
real_categories.loc[:, "Main_Color"] = encoded

# %%
#Encode gems
encoded, category_code = pd.factorize(real_categories["Main_Metal"])
real_categories.loc[:, "Main_Metal"] = encoded

# %%
real_categories.head()
# Out:
#             Order_Datetime             Order_ID           Product_Id  \
# 1  2018-12-02 13:53:42 UTC  1925511016616034733  1842214461889315556
# 2  2018-12-02 17:44:02 UTC  1925626951238681511  1835566849434059453
# 3  2018-12-02 21:30:19 UTC  1925740842841014667  1873936840742928865
# 4  2018-12-02 22:09:34 UTC  1925760595336888995  1835566854827934449
# 5  2018-12-02 22:09:34 UTC  1925760595336888995  1600021442638905547
#
#    SKU_Quantity   Category_ID Category  Brand_ID  Price_USD       User_ID  \
# 1             1  1.806829e+18        0       1.0      54.66  1.515916e+18
# 2             1  1.806829e+18        0       0.0      88.90  1.515916e+18
# 3             1  1.806829e+18        1       0.0     417.67  1.515916e+18
# 4             1  1.806829e+18        2       1.0     102.27  1.515916e+18
# 5             1  1.806829e+18        2       0.0     150.55  1.515916e+18
#
#   Target_Gender Main_Color Main_Metal Main_Gem
# 1             0          0          0        0
# 2             0          1          0        1
# 3            -1          1          0        2
# 4            -1          1          0       -1
# 5            -1          1          0        1

# %%
real_categories.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 80458 entries, 1 to 95909
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Order_Datetime  80458 non-null  object
#  1   Order_ID        80458 non-null  int64
#  2   Product_Id      80458 non-null  int64
#  3   SKU_Quantity    80458 non-null  int64
#  4   Category_ID     80458 non-null  float64
#  5   Category        80458 non-null  object
#  6   Brand_ID        76991 non-null  float64
#  7   Price_USD       80458 non-null  float64
#  8   User_ID         80458 non-null  float64
#  9   Target_Gender   80458 non-null  object
#  10  Main_Color      80458 non-null  object
#  11  Main_Metal      80458 non-null  object
#  12  Main_Gem        80458 non-null  object
# dtypes: float64(4), int64(3), object(6)
# memory usage: 10.6+ MB

# %%
# Feature correlation
correlations = real_categories.drop(labels = ["Order_Datetime", "User_ID", "Order_ID", "Product_Id"], axis = 1).corr(method = "spearman")

# %%
correlations
# Out:
#                SKU_Quantity  Category_ID  Category  Brand_ID  Price_USD  \
# SKU_Quantity            NaN          NaN       NaN       NaN        NaN
# Category_ID             NaN     1.000000 -0.886212  0.111328  -0.296495
# Category                NaN    -0.886212  1.000000 -0.111680   0.267257
# Brand_ID                NaN     0.111328 -0.111680  1.000000  -0.018428
# Price_USD               NaN    -0.296495  0.267257 -0.018428   1.000000
# Target_Gender           NaN     0.106286 -0.124101  0.623701   0.049532
# Main_Color              NaN     0.003396 -0.059402  0.100816   0.013177
# Main_Metal              NaN     0.157834  0.105056  0.003835  -0.173050
# Main_Gem                NaN     0.050483 -0.082944  0.076277  -0.006630
#
#                Target_Gender  Main_Color  Main_Metal  Main_Gem
# SKU_Quantity             NaN         NaN         NaN       NaN
# Category_ID         0.106286    0.003396    0.157834  0.050483
# Category           -0.124101   -0.059402    0.105056 -0.082944
# Brand_ID            0.623701    0.100816    0.003835  0.076277
# Price_USD           0.049532    0.013177   -0.173050 -0.006630
# Target_Gender       1.000000    0.056950   -0.046436  0.166125
# Main_Color          0.056950    1.000000   -0.238080  0.136232
# Main_Metal         -0.046436   -0.238080    1.000000 -0.055603
# Main_Gem            0.166125    0.136232   -0.055603  1.000000

# %% [markdown]
# Observation: SKU_Quantity indicated NAN all throough and showing no correlation with other features.

# %%
# Correlation heatmap
plt.figure(figsize = (10, 10))

sns.heatmap(correlations, annot = True, center = .3)

plt.show(); plt.close()

# %% [markdown]
# Observation: From the Correlation matrix, the SKU_Quantity has no value and do its empty. It can be observed that we have a weak to moderate correlation between our features. However, we go further to analyze and have an explicit idea of those features that were correlated.

# %%
# Set coreelation Limits
upper = 1
lower = 0.2

# %%
# Explicitly obtain correlated features
correlated_columns = {
    column: correlations[(correlations[column] > lower) & (upper > correlations[column])].index.tolist()
    for column in correlations.columns
}

# %%
correlated_columns
# Out:
# {'SKU_Quantity': [],
#  'Category_ID': [],
#  'Category': ['Price_USD'],
#  'Brand_ID': ['Target_Gender'],
#  'Price_USD': ['Category'],
#  'Target_Gender': ['Brand_ID'],
#  'Main_Color': [],
#  'Main_Metal': [],
#  'Main_Gem': []}

# %% [markdown]
# ### Data Implications
# Based on our findings, we have drawn the following observations:
#
# 1. Missing values: There are alot of missing values in the dataset. This may be fixed either by value imputation or missingness encoding.
# 2. Data corruption: Some variables, (e.g. jewelry_category) contain corrupt values.
# 3. Rare values: Some features have some values that occur rarely. A prime instance of this is the Target_Gender column, where the male gender is rarely represented. Sometimes, these are data issues. Other times, like in this case, this can be a true reflection of the distribution from which the data is generated.
# 4. Low cardinality of feature invariance: The SKU_Quantity feature only has one unique value (e.g. 1). This feature provides no new information.
# 5. Target skew: The target variable is highly right-skewed. This can present an issue during training.
# 6. Correlation: For the most part, the features exhibit low multicollinearity, hence ensuring feature independence. However, the target variable exhibits a low correlation with the independence variables.

# %% [markdown]
# ### 03. Data Preparation

# %% [markdown]
# Based on the Data implications discovered, the following steps will be experimented upon for the data preparation stage.
#
# 1. Missing Values: The missing values will be treated via algorithmic method - SimpleImputer.
# 2. Feature Encoding: The categorical features will be encoded.
# 3. Redundant Features: Certain features will be eliminated for a number of reasons. These are:
#      A. SKU_Quantity: Feature invariance
#      B. Order_ID: Simple identifier has no real-world influence on jewelry price.
#      C. Product_ID: Same with Order_ID.
#      D. Order_Datetime: Avoid data leakage; would likely not be available in real-world.
#
# 4. Target Skew: The target variable is strongly right-skewed. This can be an issue when learning a mapping from the data space to the label space. This issue will be fixed using the TransformedTargetRegressor utility.
#
# NOTE: Most of the data preparation steps will be carried out via the use of Pipeline class from Sci-Kit learn. The Pipeline object allows us to chain transformers and estimators sequentially for use as one composite object.
#
# High level steps:
#    1. Eliminate less useful features
#    2. Extract records with actual categories.
#    3. Encode categorical features (if required).
#    4. Account for target skew.
#    5. Fix missing values.

# %%
# Columns to eliminate
columns_to_eliminate = [
    "SKU_Quantity",
    "Order_ID",
    "Product_Id",
    "User_ID",
    "Category_ID"
]

# %%
# Eliminate unused features
data.drop(labels = columns_to_eliminate, axis = 1, inplace = True)

# %%
data.shape
# Out:
# (95910, 8)

# %%
# Eliminate unused features
data.drop(labels = ["Order_Datetime"], axis = 1, inplace = True)

# %%
data.head()
# Out:
#            Category  Brand_ID  Price_USD Target_Gender Main_Color Main_Metal  \
# 0               NaN       NaN     212.14           NaN     yellow       gold
# 1   jewelry.pendant       1.0      54.66             f      white       gold
# 2   jewelry.pendant       0.0      88.90             f        red       gold
# 3  jewelry.necklace       0.0     417.67           NaN        red       gold
# 4   jewelry.earring       1.0     102.27           NaN        red       gold
#
#    Main_Gem
# 0       NaN
# 1  sapphire
# 2   diamond
# 3  amethyst
# 4       NaN

# %% [markdown]
# Observation: We now have the right features left behind.

# %%
# Eliminate unrealistic categories
data = data.loc[data["Category"].isin(categories), :]

# %%
data.shape
# Out:
# (80458, 7)

# %% [markdown]
# Observation: About 15,000 rows that were corrupted has been eliminated.

# %%
# Split data
from sklearn.model_selection import train_test_split

# %%
#Seperate features from labels
X, y = data.drop(labels = ["Price_USD"], axis = 1), data["Price_USD"]

# %%
# Create test, train and splits
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1)

# %%
X_train.head()
# Out:
#                Category  Brand_ID Target_Gender Main_Color Main_Metal Main_Gem
# 35013      jewelry.ring       0.0           NaN        red       gold  diamond
# 32317   jewelry.earring       0.0           NaN        red       gold  diamond
# 48810  jewelry.bracelet       1.0             f        NaN     silver   spinel
# 18452      jewelry.ring       0.0           NaN        red       gold      NaN
# 30290      jewelry.ring       1.0             f        red       gold   fianit

# %%
y_train.head()
# Out:
# 35013    561.51
# 32317    677.95
# 48810     34.11
# 18452    133.55
# 30290    331.37
# Name: Price_USD, dtype: float64

# %% [markdown]
# ### 04. Data Modelling

# %% [markdown]
# 1. Linear Regression,
# 2. Extremely Random Forest (ExtraTrees),
# 3. Adaptive Boosting (AdaBoost) and
# 4. Catboost.

# %% [markdown]
# 1. Encode categorical features (if required).
# 2.
# Account for target skew.3.
# Fix missing values.

# %%
from sklearn.preprocessing import OrdinalEncoder, LabelEncoder, OneHotEncoder
from sklearn.compose import TransformedTargetRegressor, ColumnTransformer
from sklearn.impute import SimpleImputer

from sklearn.linear_model import LinearRegression
from sklearn.ensemble import AdaBoostRegressor, ExtraTreesRegressor
from catboost import CatBoostRegressor

# %%
from sklearn.pipeline import Pipeline

# %%
def generate_pipeline(model, column_indices, categorical_indices, fill_missing = True, one_hot = True, label_encode = False):\
   # Fix missing values
    first_transformer = ColumnTransformer(
        transformers = [
            ("imputer", SimpleImputer(strategy = "most_frequent"), column_indices)
        ],
        remainder = "passthrough",
        sparse_threshold = 0.
    )

    # One hot encode
    second_transformer = ColumnTransformer(
        transformers = [
            ("one_hot", OneHotEncoder(handle_unknown='ignore'), categorical_indices)
        ],
        remainder = "passthrough",
        sparse_threshold = 0.
    )
    encoder = OneHotEncoder(handle_unknown='ignore')
    # Label encode
    third_transformer = ColumnTransformer(
        transformers = [
            ("ordinal", OrdinalEncoder(), categorical_indices)
        ],
        remainder = "passthrough",
        sparse_threshold = 0.
    )

    steps = []

    if fill_missing:
        steps.append(("first", first_transformer))

    if label_encode:
        steps.append(("third", third_transformer))

    if one_hot:
        steps.append(("second", second_transformer))

    steps.append(("model", model))

    model_pipe = Pipeline(steps = steps)

    return model_pipe

# %%
X.head()
# Out:
#            Category  Brand_ID Target_Gender Main_Color Main_Metal  Main_Gem
# 1   jewelry.pendant       1.0             f      white       gold  sapphire
# 2   jewelry.pendant       0.0             f        red       gold   diamond
# 3  jewelry.necklace       0.0           NaN        red       gold  amethyst
# 4   jewelry.earring       1.0           NaN        red       gold       NaN
# 5   jewelry.earring       0.0           NaN        red       gold   diamond

# %%
# Geneqrate Indices
columns = X.columns.tolist()

column_indices = [columns.index(c) for c in columns]
categorical_features = [c for c in columns if c not in ["Brand_ID"]]
categorical_indices = [columns.index(c) for c in categorical_features]

# %%
categorical_indices
# Out:
# [0, 2, 3, 4, 5]

# %%
# CatBoost pipeline
cat_pipe = generate_pipeline(
    CatBoostRegressor(loss_function = "RMSE", iterations = 10000, learning_rate = 0.1, one_hot_max_size = 2),
    column_indices,
    categorical_indices,
    fill_missing = False, one_hot = False, label_encode = True
)

# %%
# LR pipeline
lin_pipe = generate_pipeline(
    LinearRegression(),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
# AdaBoost pipeline
ada_pipe = generate_pipeline(
    AdaBoostRegressor(loss = "exponential", n_estimators = 1000, learning_rate = 0.1),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
# ExtraTrees pipeline
extra_pipe = generate_pipeline(
    ExtraTreesRegressor(criterion = "friedman_mse", n_estimators = 1000, bootstrap = True),
    column_indices,
    categorical_indices,
    fill_missing = True, one_hot = True, label_encode = False
)

# %%
from sklearn.preprocessing import PowerTransformer

# %%
# Transform targets
cat_pipe = TransformedTargetRegressor(regressor = cat_pipe, transformer = PowerTransformer(method = "box-cox"))
ada_pipe = TransformedTargetRegressor(regressor = ada_pipe, transformer = PowerTransformer(method = "box-cox"))
lin_pipe = TransformedTargetRegressor(regressor = lin_pipe, transformer = PowerTransformer(method = "box-cox"))
extra_pipe = TransformedTargetRegressor(regressor = extra_pipe, transformer = PowerTransformer(method = "box-cox"))

# %%
X.head()
# Out:
#            Category  Brand_ID Target_Gender Main_Color Main_Metal  Main_Gem
# 1   jewelry.pendant       1.0             f      white       gold  sapphire
# 2   jewelry.pendant       0.0             f        red       gold   diamond
# 3  jewelry.necklace       0.0           NaN        red       gold  amethyst
# 4   jewelry.earring       1.0           NaN        red       gold       NaN
# 5   jewelry.earring       0.0           NaN        red       gold   diamond

# %%
print(X_train.isnull().sum())
# Out:
# Category             0
# Brand_ID          3120
# Target_Gender    32475
# Main_Color        1929
# Main_Metal          81
# Main_Gem         17541
# dtype: int64

# %%
y_train.head()
# Out:
# 35013    561.51
# 32317    677.95
# 48810     34.11
# 18452    133.55
# 30290    331.37
# Name: Price_USD, dtype: float64

# %%
# Fit CatBoost
cat_pipe.fit(X_train, y_train)
# Out:
# Streaming output truncated to the last 5000 lines.
# 5000:	learn: 0.6157828	total: 53.2s	remaining: 53.2s
# 5001:	learn: 0.6157825	total: 53.2s	remaining: 53.2s
# 5002:	learn: 0.6157824	total: 53.2s	remaining: 53.2s
# 5003:	learn: 0.6157822	total: 53.2s	remaining: 53.2s
# 5004:	learn: 0.6157820	total: 53.3s	remaining: 53.1s
# 5005:	learn: 0.6157820	total: 53.3s	remaining: 53.1s
# 5006:	learn: 0.6157819	total: 53.3s	remaining: 53.1s
# 5007:	learn: 0.6157818	total: 53.3s	remaining: 53.1s
# 5008:	learn: 0.6157818	total: 53.3s	remaining: 53.1s
# 5009:	learn: 0.6157795	total: 53.3s	remaining: 53.1s
# 5010:	learn: 0.6157790	total: 53.3s	remaining: 53.1s
# 5011:	learn: 0.6157789	total: 53.3s	remaining: 53.1s
# 5012:	learn: 0.6157789	total: 53.3s	remaining: 53s
# 5013:	learn: 0.6157789	total: 53.3s	remaining: 53s
# 5014:	learn: 0.6157789	total: 53.3s	remaining: 53s
# 5015:	learn: 0.6157789	total: 53.3s	remaining: 53s
# 5016:	learn: 0.6157787	total: 53.3s	remaining: 53s
# 5017:	learn: 0.6157787	total: 53.4s	remaining: 53s
# 5018:	learn: 0.6157785	total: 53.4s	remaining: 53s
# 5019:	learn: 0.6157785	total: 53.4s	remaining: 53s
# 5020:	learn: 0.6157785	total: 53.4s	remaining: 52.9s
# 5021:	learn: 0.6157784	total: 53.4s	remaining: 52.9s
# 5022:	learn: 0.6157783	total: 53.4s	remaining: 52.9s
# 5023:	learn: 0.6157780	total: 53.4s	remaining: 52.9s
# 5024:	learn: 0.6157779	total: 53.4s	remaining: 52.9s
# 5025:	learn: 0.6157777	total: 53.4s	remaining: 52.9s
# 5026:	learn: 0.6157775	total: 53.5s	remaining: 52.9s
# 5027:	learn: 0.6157774	total: 53.5s	remaining: 52.9s
# 5028:	learn: 0.6157773	total: 53.5s	remaining: 52.9s
# 5029:	learn: 0.6157772	total: 53.5s	remaining: 52.9s
# 5030:	learn: 0.6157770	total: 53.5s	remaining: 52.8s
# 5031:	learn: 0.6157770	total: 53.5s	remaining: 52.8s
# 5032:	learn: 0.6157770	total: 53.5s	remaining: 52.8s
# 5033:	learn: 0.6157770	total: 53.5s	remaining: 52.8s
# 5034:	learn: 0.6157770	total: 53.5s	remaining: 52.8s
# 5035:	learn: 0.6157762	total: 53.5s	remaining: 52.8s
# 5036:	learn: 0.6157752	total: 53.6s	remaining: 52.8s
# 5037:	learn: 0.6157749	total: 53.6s	remaining: 52.8s
# 5038:	learn: 0.6157749	total: 53.6s	remaining: 52.7s
# 5039:	learn: 0.6157749	total: 53.6s	remaining: 52.7s
# 5040:	learn: 0.6157737	total: 53.6s	remaining: 52.7s
# 5041:	learn: 0.6157737	total: 53.6s	remaining: 52.7s
# 5042:	learn: 0.6157736	total: 53.6s	remaining: 52.7s
# 5043:	learn: 0.6157735	total: 53.6s	remaining: 52.7s
# 5044:	learn: 0.6157735	total: 53.6s	remaining: 52.7s
# 5045:	learn: 0.6157734	total: 53.6s	remaining: 52.7s
# 5046:	learn: 0.6157734	total: 53.6s	remaining: 52.6s
# 5047:	learn: 0.6157734	total: 53.7s	remaining: 52.6s
# 5048:	learn: 0.6157734	total: 53.7s	remaining: 52.6s
# 5049:	learn: 0.6157733	total: 53.7s	remaining: 52.6s
# 5050:	learn: 0.6157733	total: 53.7s	remaining: 52.6s
# 5051:	learn: 0.6157732	total: 53.7s	remaining: 52.6s
# 5052:	learn: 0.6157732	total: 53.7s	remaining: 52.6s
# 5053:	learn: 0.6157731	total: 53.7s	remaining: 52.6s
# 5054:	learn: 0.6157731	total: 53.7s	remaining: 52.5s
# 5055:	learn: 0.6157731	total: 53.7s	remaining: 52.5s
# 5056:	learn: 0.6157731	total: 53.7s	remaining: 52.5s
# 5057:	learn: 0.6157731	total: 53.7s	remaining: 52.5s
# 5058:	learn: 0.6157730	total: 53.7s	remaining: 52.5s
# 5059:	learn: 0.6157730	total: 53.8s	remaining: 52.5s
# 5060:	learn: 0.6157727	total: 53.8s	remaining: 52.5s
# 5061:	learn: 0.6157727	total: 53.8s	remaining: 52.5s
# 5062:	learn: 0.6157726	total: 53.8s	remaining: 52.5s
# 5063:	learn: 0.6157707	total: 53.8s	remaining: 52.4s
# 5064:	learn: 0.6157704	total: 53.8s	remaining: 52.4s
# 5065:	learn: 0.6157703	total: 53.8s	remaining: 52.4s
# 5066:	learn: 0.6157703	total: 53.8s	remaining: 52.4s
# 5067:	learn: 0.6157703	total: 53.8s	remaining: 52.4s
# 5068:	learn: 0.6157703	total: 53.8s	remaining: 52.4s
# 5069:	learn: 0.6157702	total: 53.9s	remaining: 52.4s
# 5070:	learn: 0.6157702	total: 53.9s	remaining: 52.4s
# 5071:	learn: 0.6157702	total: 53.9s	remaining: 52.3s
# 5072:	learn: 0.6157699	total: 53.9s	remaining: 52.3s
# 5073:	learn: 0.6157699	total: 53.9s	remaining: 52.3s
# 5074:	learn: 0.6157698	total: 53.9s	remaining: 52.3s
# 5075:	learn: 0.6157698	total: 53.9s	remaining: 52.3s
# 5076:	learn: 0.6157698	total: 53.9s	remaining: 52.3s
# 5077:	learn: 0.6157698	total: 53.9s	remaining: 52.3s
# 5078:	learn: 0.6157695	total: 53.9s	remaining: 52.3s
# 5079:	learn: 0.6157694	total: 53.9s	remaining: 52.2s
# 5080:	learn: 0.6157687	total: 54s	remaining: 52.2s
# 5081:	learn: 0.6157684	total: 54s	remaining: 52.2s
# 5082:	learn: 0.6157683	total: 54s	remaining: 52.2s
# 5083:	learn: 0.6157682	total: 54s	remaining: 52.2s
# 5084:	learn: 0.6157682	total: 54s	remaining: 52.2s
# 5085:	learn: 0.6157677	total: 54s	remaining: 52.2s
# 5086:	learn: 0.6157675	total: 54s	remaining: 52.2s
# 5087:	learn: 0.6157675	total: 54s	remaining: 52.2s
# 5088:	learn: 0.6157675	total: 54s	remaining: 52.1s
# 5089:	learn: 0.6157671	total: 54s	remaining: 52.1s
# 5090:	learn: 0.6157670	total: 54.1s	remaining: 52.1s
# 5091:	learn: 0.6157670	total: 54.1s	remaining: 52.1s
# 5092:	learn: 0.6157670	total: 54.1s	remaining: 52.1s
# 5093:	learn: 0.6157670	total: 54.1s	remaining: 52.1s
# 5094:	learn: 0.6157669	total: 54.1s	remaining: 52.1s
# 5095:	learn: 0.6157669	total: 54.1s	remaining: 52.1s
# 5096:	learn: 0.6157668	total: 54.1s	remaining: 52s
# 5097:	learn: 0.6157665	total: 54.1s	remaining: 52s
# 5098:	learn: 0.6157664	total: 54.1s	remaining: 52s
# 5099:	learn: 0.6157664	total: 54.1s	remaining: 52s
# 5100:	learn: 0.6157663	total: 54.1s	remaining: 52s
# 5101:	learn: 0.6157663	total: 54.1s	remaining: 52s
# 5102:	learn: 0.6157663	total: 54.1s	remaining: 52s
# 5103:	learn: 0.6157661	total: 54.2s	remaining: 51.9s
# 5104:	learn: 0.6157660	total: 54.2s	remaining: 51.9s
# 5105:	learn: 0.6157658	total: 54.2s	remaining: 51.9s
# 5106:	learn: 0.6157657	total: 54.2s	remaining: 51.9s
# 5107:	learn: 0.6157656	total: 54.2s	remaining: 51.9s
# 5108:	learn: 0.6157656	total: 54.2s	remaining: 51.9s
# 5109:	learn: 0.6157656	total: 54.2s	remaining: 51.9s
# 5110:	learn: 0.6157656	total: 54.2s	remaining: 51.9s
# 5111:	learn: 0.6157655	total: 54.2s	remaining: 51.9s
# 5112:	learn: 0.6157640	total: 54.2s	remaining: 51.8s
# 5113:	learn: 0.6157640	total: 54.2s	remaining: 51.8s
# 5114:	learn: 0.6157637	total: 54.3s	remaining: 51.8s
# 5115:	learn: 0.6157637	total: 54.3s	remaining: 51.8s
# 5116:	learn: 0.6157637	total: 54.3s	remaining: 51.8s
# 5117:	learn: 0.6157634	total: 54.3s	remaining: 51.8s
# 5118:	learn: 0.6157634	total: 54.3s	remaining: 51.8s
# 5119:	learn: 0.6157634	total: 54.3s	remaining: 51.8s
# 5120:	learn: 0.6157634	total: 54.3s	remaining: 51.7s
# 5121:	learn: 0.6157634	total: 54.3s	remaining: 51.7s
# 5122:	learn: 0.6157634	total: 54.3s	remaining: 51.7s
# 5123:	learn: 0.6157634	total: 54.3s	remaining: 51.7s
# 5124:	learn: 0.6157632	total: 54.4s	remaining: 51.7s
# 5125:	learn: 0.6157632	total: 54.4s	remaining: 51.7s
# 5126:	learn: 0.6157630	total: 54.4s	remaining: 51.7s
# 5127:	learn: 0.6157625	total: 54.4s	remaining: 51.7s
# 5128:	learn: 0.6157625	total: 54.4s	remaining: 51.6s
# 5129:	learn: 0.6157624	total: 54.4s	remaining: 51.6s
# 5130:	learn: 0.6157621	total: 54.4s	remaining: 51.6s
# 5131:	learn: 0.6157616	total: 54.4s	remaining: 51.6s
# 5132:	learn: 0.6157616	total: 54.4s	remaining: 51.6s
# 5133:	learn: 0.6157616	total: 54.4s	remaining: 51.6s
# 5134:	learn: 0.6157616	total: 54.5s	remaining: 51.6s
# 5135:	learn: 0.6157616	total: 54.5s	remaining: 51.6s
# 5136:	learn: 0.6157601	total: 54.5s	remaining: 51.6s
# 5137:	learn: 0.6157594	total: 54.5s	remaining: 51.6s
# 5138:	learn: 0.6157593	total: 54.5s	remaining: 51.5s
# 5139:	learn: 0.6157593	total: 54.5s	remaining: 51.5s
# 5140:	learn: 0.6157592	total: 54.5s	remaining: 51.5s
# 5141:	learn: 0.6157591	total: 54.5s	remaining: 51.5s
# 5142:	learn: 0.6157589	total: 54.5s	remaining: 51.5s
# 5143:	learn: 0.6157589	total: 54.5s	remaining: 51.5s
# 5144:	learn: 0.6157589	total: 54.5s	remaining: 51.5s
# 5145:	learn: 0.6157588	total: 54.6s	remaining: 51.5s
# 5146:	learn: 0.6157588	total: 54.6s	remaining: 51.4s
# 5147:	learn: 0.6157588	total: 54.6s	remaining: 51.4s
# 5148:	learn: 0.6157588	total: 54.6s	remaining: 51.4s
# 5149:	learn: 0.6157587	total: 54.6s	remaining: 51.4s
# 5150:	learn: 0.6157586	total: 54.6s	remaining: 51.4s
# 5151:	learn: 0.6157586	total: 54.6s	remaining: 51.4s
# 5152:	learn: 0.6157585	total: 54.6s	remaining: 51.4s
# 5153:	learn: 0.6157585	total: 54.6s	remaining: 51.4s
# 5154:	learn: 0.6157585	total: 54.6s	remaining: 51.3s
# 5155:	learn: 0.6157583	total: 54.6s	remaining: 51.3s
# 5156:	learn: 0.6157583	total: 54.6s	remaining: 51.3s
# 5157:	learn: 0.6157583	total: 54.7s	remaining: 51.3s
# 5158:	learn: 0.6157582	total: 54.7s	remaining: 51.3s
# 5159:	learn: 0.6157582	total: 54.7s	remaining: 51.3s
# 5160:	learn: 0.6157578	total: 54.7s	remaining: 51.3s
# 5161:	learn: 0.6157578	total: 54.7s	remaining: 51.3s
# 5162:	learn: 0.6157578	total: 54.7s	remaining: 51.3s
# 5163:	learn: 0.6157566	total: 54.7s	remaining: 51.2s
# 5164:	learn: 0.6157566	total: 54.7s	remaining: 51.2s
# 5165:	learn: 0.6157565	total: 54.7s	remaining: 51.2s
# 5166:	learn: 0.6157565	total: 54.7s	remaining: 51.2s
# 5167:	learn: 0.6157564	total: 54.8s	remaining: 51.2s
# 5168:	learn: 0.6157564	total: 54.8s	remaining: 51.2s
# 5169:	learn: 0.6157563	total: 54.8s	remaining: 51.2s
# 5170:	learn: 0.6157563	total: 54.8s	remaining: 51.2s
# 5171:	learn: 0.6157563	total: 54.8s	remaining: 51.1s
# 5172:	learn: 0.6157563	total: 54.8s	remaining: 51.1s
# 5173:	learn: 0.6157562	total: 54.8s	remaining: 51.1s
# 5174:	learn: 0.6157562	total: 54.8s	remaining: 51.1s
# 5175:	learn: 0.6157561	total: 54.8s	remaining: 51.1s
# 5176:	learn: 0.6157561	total: 54.8s	remaining: 51.1s
# 5177:	learn: 0.6157556	total: 54.8s	remaining: 51.1s
# 5178:	learn: 0.6157556	total: 54.9s	remaining: 51.1s
# 5179:	learn: 0.6157556	total: 54.9s	remaining: 51s
# 5180:	learn: 0.6157551	total: 54.9s	remaining: 51s
# 5181:	learn: 0.6157551	total: 54.9s	remaining: 51s
# 5182:	learn: 0.6157546	total: 54.9s	remaining: 51s
# 5183:	learn: 0.6157546	total: 54.9s	remaining: 51s
# 5184:	learn: 0.6157545	total: 54.9s	remaining: 51s
# 5185:	learn: 0.6157538	total: 54.9s	remaining: 51s
# 5186:	learn: 0.6157538	total: 54.9s	remaining: 51s
# 5187:	learn: 0.6157538	total: 54.9s	remaining: 50.9s
# 5188:	learn: 0.6157538	total: 54.9s	remaining: 50.9s
# 5189:	learn: 0.6157537	total: 54.9s	remaining: 50.9s
# 5190:	learn: 0.6157535	total: 55s	remaining: 50.9s
# 5191:	learn: 0.6157522	total: 55s	remaining: 50.9s
# 5192:	learn: 0.6157518	total: 55s	remaining: 50.9s
# 5193:	learn: 0.6157518	total: 55s	remaining: 50.9s
# 5194:	learn: 0.6157517	total: 55s	remaining: 50.9s
# 5195:	learn: 0.6157517	total: 55s	remaining: 50.9s
# 5196:	learn: 0.6157516	total: 55s	remaining: 50.8s
# 5197:	learn: 0.6157513	total: 55s	remaining: 50.8s
# 5198:	learn: 0.6157512	total: 55s	remaining: 50.8s
# 5199:	learn: 0.6157511	total: 55s	remaining: 50.8s
# 5200:	learn: 0.6157511	total: 55.1s	remaining: 50.8s
# 5201:	learn: 0.6157511	total: 55.1s	remaining: 50.8s
# 5202:	learn: 0.6157511	total: 55.1s	remaining: 50.8s
# 5203:	learn: 0.6157510	total: 55.1s	remaining: 50.8s
# 5204:	learn: 0.6157509	total: 55.1s	remaining: 50.7s
# 5205:	learn: 0.6157509	total: 55.1s	remaining: 50.7s
# 5206:	learn: 0.6157508	total: 55.1s	remaining: 50.7s
# 5207:	learn: 0.6157508	total: 55.1s	remaining: 50.7s
# 5208:	learn: 0.6157508	total: 55.1s	remaining: 50.7s
# 5209:	learn: 0.6157506	total: 55.1s	remaining: 50.7s
# 5210:	learn: 0.6157505	total: 55.1s	remaining: 50.7s
# 5211:	learn: 0.6157505	total: 55.1s	remaining: 50.7s
# 5212:	learn: 0.6157504	total: 55.2s	remaining: 50.6s
# 5213:	learn: 0.6157504	total: 55.2s	remaining: 50.6s
# 5214:	learn: 0.6157504	total: 55.2s	remaining: 50.6s
# 5215:	learn: 0.6157504	total: 55.2s	remaining: 50.6s
# 5216:	learn: 0.6157492	total: 55.2s	remaining: 50.6s
# 5217:	learn: 0.6157492	total: 55.2s	remaining: 50.6s
# 5218:	learn: 0.6157492	total: 55.2s	remaining: 50.6s
# 5219:	learn: 0.6157492	total: 55.2s	remaining: 50.6s
# 5220:	learn: 0.6157492	total: 55.2s	remaining: 50.6s
# 5221:	learn: 0.6157492	total: 55.2s	remaining: 50.5s
# 5222:	learn: 0.6157489	total: 55.3s	remaining: 50.5s
# 5223:	learn: 0.6157485	total: 55.3s	remaining: 50.5s
# 5224:	learn: 0.6157484	total: 55.3s	remaining: 50.5s
# 5225:	learn: 0.6157483	total: 55.3s	remaining: 50.5s
# 5226:	learn: 0.6157482	total: 55.3s	remaining: 50.5s
# 5227:	learn: 0.6157482	total: 55.3s	remaining: 50.5s
# 5228:	learn: 0.6157479	total: 55.3s	remaining: 50.5s
# 5229:	learn: 0.6157478	total: 55.3s	remaining: 50.5s
# 5230:	learn: 0.6157478	total: 55.3s	remaining: 50.4s
# 5231:	learn: 0.6157465	total: 55.3s	remaining: 50.4s
# 5232:	learn: 0.6157465	total: 55.3s	remaining: 50.4s
# 5233:	learn: 0.6157465	total: 55.4s	remaining: 50.4s
# 5234:	learn: 0.6157462	total: 55.4s	remaining: 50.4s
# 5235:	learn: 0.6157460	total: 55.4s	remaining: 50.4s
# 5236:	learn: 0.6157447	total: 55.4s	remaining: 50.4s
# 5237:	learn: 0.6157447	total: 55.4s	remaining: 50.4s
# 5238:	learn: 0.6157447	total: 55.4s	remaining: 50.3s
# 5239:	learn: 0.6157444	total: 55.4s	remaining: 50.3s
# 5240:	learn: 0.6157444	total: 55.4s	remaining: 50.3s
# 5241:	learn: 0.6157443	total: 55.4s	remaining: 50.3s
# 5242:	learn: 0.6157443	total: 55.4s	remaining: 50.3s
# 5243:	learn: 0.6157442	total: 55.4s	remaining: 50.3s
# 5244:	learn: 0.6157442	total: 55.5s	remaining: 50.3s
# 5245:	learn: 0.6157442	total: 55.5s	remaining: 50.3s
# 5246:	learn: 0.6157442	total: 55.5s	remaining: 50.3s
# 5247:	learn: 0.6157442	total: 55.5s	remaining: 50.2s
# 5248:	learn: 0.6157442	total: 55.5s	remaining: 50.2s
# 5249:	learn: 0.6157441	total: 55.5s	remaining: 50.2s
# 5250:	learn: 0.6157440	total: 55.5s	remaining: 50.2s
# 5251:	learn: 0.6157440	total: 55.5s	remaining: 50.2s
# 5252:	learn: 0.6157440	total: 55.5s	remaining: 50.2s
# 5253:	learn: 0.6157439	total: 55.5s	remaining: 50.2s
# 5254:	learn: 0.6157438	total: 55.6s	remaining: 50.2s
# 5255:	learn: 0.6157438	total: 55.6s	remaining: 50.2s
# 5256:	learn: 0.6157437	total: 55.6s	remaining: 50.1s
# 5257:	learn: 0.6157437	total: 55.6s	remaining: 50.1s
# 5258:	learn: 0.6157437	total: 55.6s	remaining: 50.1s
# 5259:	learn: 0.6157437	total: 55.6s	remaining: 50.1s
# 5260:	learn: 0.6157435	total: 55.6s	remaining: 50.1s
# 5261:	learn: 0.6157433	total: 55.6s	remaining: 50.1s
# 5262:	learn: 0.6157433	total: 55.6s	remaining: 50.1s
# 5263:	learn: 0.6157433	total: 55.6s	remaining: 50s
# 5264:	learn: 0.6157432	total: 55.6s	remaining: 50s
# 5265:	learn: 0.6157432	total: 55.7s	remaining: 50s
# 5266:	learn: 0.6157432	total: 55.7s	remaining: 50s
# 5267:	learn: 0.6157431	total: 55.7s	remaining: 50s
# 5268:	learn: 0.6157431	total: 55.7s	remaining: 50s
# 5269:	learn: 0.6157431	total: 55.7s	remaining: 50s
# 5270:	learn: 0.6157431	total: 55.7s	remaining: 50s
# 5271:	learn: 0.6157423	total: 55.7s	remaining: 50s
# 5272:	learn: 0.6157423	total: 55.7s	remaining: 49.9s
# 5273:	learn: 0.6157403	total: 55.7s	remaining: 49.9s
# 5274:	learn: 0.6157403	total: 55.7s	remaining: 49.9s
# 5275:	learn: 0.6157401	total: 55.7s	remaining: 49.9s
# 5276:	learn: 0.6157401	total: 55.8s	remaining: 49.9s
# 5277:	learn: 0.6157401	total: 55.8s	remaining: 49.9s
# 5278:	learn: 0.6157401	total: 55.8s	remaining: 49.9s
# 5279:	learn: 0.6157386	total: 55.8s	remaining: 49.9s
# 5280:	learn: 0.6157386	total: 55.8s	remaining: 49.8s
# 5281:	learn: 0.6157381	total: 55.8s	remaining: 49.8s
# 5282:	learn: 0.6157381	total: 55.8s	remaining: 49.8s
# 5283:	learn: 0.6157380	total: 55.8s	remaining: 49.8s
# 5284:	learn: 0.6157379	total: 55.8s	remaining: 49.8s
# 5285:	learn: 0.6157378	total: 55.8s	remaining: 49.8s
# 5286:	learn: 0.6157378	total: 55.8s	remaining: 49.8s
# 5287:	learn: 0.6157378	total: 55.9s	remaining: 49.8s
# 5288:	learn: 0.6157376	total: 55.9s	remaining: 49.8s
# 5289:	learn: 0.6157373	total: 55.9s	remaining: 49.8s
# 5290:	learn: 0.6157373	total: 55.9s	remaining: 49.7s
# 5291:	learn: 0.6157372	total: 55.9s	remaining: 49.7s
# 5292:	learn: 0.6157370	total: 55.9s	remaining: 49.7s
# 5293:	learn: 0.6157370	total: 55.9s	remaining: 49.7s
# 5294:	learn: 0.6157367	total: 55.9s	remaining: 49.7s
# 5295:	learn: 0.6157362	total: 55.9s	remaining: 49.7s
# 5296:	learn: 0.6157362	total: 55.9s	remaining: 49.7s
# 5297:	learn: 0.6157362	total: 56s	remaining: 49.7s
# 5298:	learn: 0.6157361	total: 56s	remaining: 49.6s
# 5299:	learn: 0.6157360	total: 56s	remaining: 49.6s
# 5300:	learn: 0.6157360	total: 56s	remaining: 49.6s
# 5301:	learn: 0.6157349	total: 56s	remaining: 49.6s
# 5302:	learn: 0.6157349	total: 56s	remaining: 49.6s
# 5303:	learn: 0.6157349	total: 56s	remaining: 49.6s
# 5304:	learn: 0.6157348	total: 56s	remaining: 49.6s
# 5305:	learn: 0.6157348	total: 56s	remaining: 49.6s
# 5306:	learn: 0.6157348	total: 56s	remaining: 49.5s
# 5307:	learn: 0.6157346	total: 56s	remaining: 49.5s
# 5308:	learn: 0.6157346	total: 56s	remaining: 49.5s
# 5309:	learn: 0.6157346	total: 56.1s	remaining: 49.5s
# 5310:	learn: 0.6157343	total: 56.1s	remaining: 49.5s
# 5311:	learn: 0.6157342	total: 56.1s	remaining: 49.5s
# 5312:	learn: 0.6157337	total: 56.1s	remaining: 49.5s
# 5313:	learn: 0.6157337	total: 56.1s	remaining: 49.5s
# 5314:	learn: 0.6157334	total: 56.1s	remaining: 49.5s
# 5315:	learn: 0.6157333	total: 56.1s	remaining: 49.4s
# 5316:	learn: 0.6157333	total: 56.1s	remaining: 49.4s
# 5317:	learn: 0.6157333	total: 56.1s	remaining: 49.4s
# 5318:	learn: 0.6157333	total: 56.1s	remaining: 49.4s
# 5319:	learn: 0.6157333	total: 56.2s	remaining: 49.4s
# 5320:	learn: 0.6157331	total: 56.2s	remaining: 49.4s
# 5321:	learn: 0.6157331	total: 56.2s	remaining: 49.4s
# 5322:	learn: 0.6157330	total: 56.2s	remaining: 49.4s
# 5323:	learn: 0.6157330	total: 56.2s	remaining: 49.3s
# 5324:	learn: 0.6157330	total: 56.2s	remaining: 49.3s
# 5325:	learn: 0.6157330	total: 56.2s	remaining: 49.3s
# 5326:	learn: 0.6157329	total: 56.2s	remaining: 49.3s
# 5327:	learn: 0.6157325	total: 56.2s	remaining: 49.3s
# 5328:	learn: 0.6157322	total: 56.2s	remaining: 49.3s
# 5329:	learn: 0.6157319	total: 56.2s	remaining: 49.3s
# 5330:	learn: 0.6157319	total: 56.2s	remaining: 49.3s
# 5331:	learn: 0.6157319	total: 56.3s	remaining: 49.3s
# 5332:	learn: 0.6157319	total: 56.3s	remaining: 49.2s
# 5333:	learn: 0.6157319	total: 56.3s	remaining: 49.2s
# 5334:	learn: 0.6157319	total: 56.3s	remaining: 49.2s
# 5335:	learn: 0.6157318	total: 56.3s	remaining: 49.2s
# 5336:	learn: 0.6157318	total: 56.3s	remaining: 49.2s
# 5337:	learn: 0.6157315	total: 56.3s	remaining: 49.2s
# 5338:	learn: 0.6157314	total: 56.3s	remaining: 49.2s
# 5339:	learn: 0.6157314	total: 56.3s	remaining: 49.2s
# 5340:	learn: 0.6157314	total: 56.3s	remaining: 49.1s
# 5341:	learn: 0.6157313	total: 56.3s	remaining: 49.1s
# 5342:	learn: 0.6157311	total: 56.4s	remaining: 49.1s
# 5343:	learn: 0.6157311	total: 56.4s	remaining: 49.1s
# 5344:	learn: 0.6157311	total: 56.4s	remaining: 49.1s
# 5345:	learn: 0.6157310	total: 56.4s	remaining: 49.1s
# 5346:	learn: 0.6157299	total: 56.4s	remaining: 49.1s
# 5347:	learn: 0.6157299	total: 56.4s	remaining: 49.1s
# 5348:	learn: 0.6157299	total: 56.4s	remaining: 49.1s
# 5349:	learn: 0.6157299	total: 56.4s	remaining: 49s
# 5350:	learn: 0.6157299	total: 56.4s	remaining: 49s
# 5351:	learn: 0.6157294	total: 56.4s	remaining: 49s
# 5352:	learn: 0.6157293	total: 56.4s	remaining: 49s
# 5353:	learn: 0.6157293	total: 56.5s	remaining: 49s
# 5354:	learn: 0.6157293	total: 56.5s	remaining: 49s
# 5355:	learn: 0.6157293	total: 56.5s	remaining: 49s
# 5356:	learn: 0.6157292	total: 56.5s	remaining: 49s
# 5357:	learn: 0.6157292	total: 56.5s	remaining: 49s
# 5358:	learn: 0.6157292	total: 56.5s	remaining: 48.9s
# 5359:	learn: 0.6157291	total: 56.5s	remaining: 48.9s
# 5360:	learn: 0.6157288	total: 56.5s	remaining: 48.9s
# 5361:	learn: 0.6157288	total: 56.5s	remaining: 48.9s
# 5362:	learn: 0.6157288	total: 56.6s	remaining: 48.9s
# 5363:	learn: 0.6157287	total: 56.6s	remaining: 48.9s
# 5364:	learn: 0.6157284	total: 56.6s	remaining: 48.9s
# 5365:	learn: 0.6157270	total: 56.6s	remaining: 48.9s
# 5366:	learn: 0.6157270	total: 56.6s	remaining: 48.8s
# 5367:	learn: 0.6157270	total: 56.6s	remaining: 48.8s
# 5368:	learn: 0.6157270	total: 56.6s	remaining: 48.8s
# 5369:	learn: 0.6157267	total: 56.6s	remaining: 48.8s
# 5370:	learn: 0.6157266	total: 56.6s	remaining: 48.8s
# 5371:	learn: 0.6157266	total: 56.6s	remaining: 48.8s
# 5372:	learn: 0.6157261	total: 56.6s	remaining: 48.8s
# 5373:	learn: 0.6157261	total: 56.6s	remaining: 48.8s
# 5374:	learn: 0.6157251	total: 56.7s	remaining: 48.7s
# 5375:	learn: 0.6157251	total: 56.7s	remaining: 48.7s
# 5376:	learn: 0.6157251	total: 56.7s	remaining: 48.7s
# 5377:	learn: 0.6157251	total: 56.7s	remaining: 48.7s
# 5378:	learn: 0.6157249	total: 56.7s	remaining: 48.7s
# 5379:	learn: 0.6157249	total: 56.7s	remaining: 48.7s
# 5380:	learn: 0.6157249	total: 56.7s	remaining: 48.7s
# 5381:	learn: 0.6157249	total: 56.7s	remaining: 48.7s
# 5382:	learn: 0.6157248	total: 56.7s	remaining: 48.7s
# 5383:	learn: 0.6157246	total: 56.7s	remaining: 48.6s
# 5384:	learn: 0.6157246	total: 56.8s	remaining: 48.6s
# 5385:	learn: 0.6157245	total: 56.8s	remaining: 48.6s
# 5386:	learn: 0.6157243	total: 56.8s	remaining: 48.6s
# 5387:	learn: 0.6157243	total: 56.8s	remaining: 48.6s
# 5388:	learn: 0.6157235	total: 56.8s	remaining: 48.6s
# 5389:	learn: 0.6157227	total: 56.8s	remaining: 48.6s
# 5390:	learn: 0.6157227	total: 56.8s	remaining: 48.6s
# 5391:	learn: 0.6157226	total: 56.8s	remaining: 48.6s
# 5392:	learn: 0.6157212	total: 56.8s	remaining: 48.5s
# 5393:	learn: 0.6157212	total: 56.8s	remaining: 48.5s
# 5394:	learn: 0.6157212	total: 56.8s	remaining: 48.5s
# 5395:	learn: 0.6157212	total: 56.8s	remaining: 48.5s
# 5396:	learn: 0.6157212	total: 56.9s	remaining: 48.5s
# 5397:	learn: 0.6157211	total: 56.9s	remaining: 48.5s
# 5398:	learn: 0.6157210	total: 56.9s	remaining: 48.5s
# 5399:	learn: 0.6157210	total: 56.9s	remaining: 48.5s
# 5400:	learn: 0.6157210	total: 56.9s	remaining: 48.4s
# 5401:	learn: 0.6157210	total: 56.9s	remaining: 48.4s
# 5402:	learn: 0.6157210	total: 56.9s	remaining: 48.4s
# 5403:	learn: 0.6157209	total: 56.9s	remaining: 48.4s
# 5404:	learn: 0.6157209	total: 56.9s	remaining: 48.4s
# 5405:	learn: 0.6157208	total: 56.9s	remaining: 48.4s
# 5406:	learn: 0.6157208	total: 57s	remaining: 48.4s
# 5407:	learn: 0.6157208	total: 57s	remaining: 48.4s
# 5408:	learn: 0.6157208	total: 57s	remaining: 48.4s
# 5409:	learn: 0.6157203	total: 57s	remaining: 48.3s
# 5410:	learn: 0.6157199	total: 57s	remaining: 48.3s
# 5411:	learn: 0.6157199	total: 57s	remaining: 48.3s
# 5412:	learn: 0.6157199	total: 57s	remaining: 48.3s
# 5413:	learn: 0.6157198	total: 57s	remaining: 48.3s
# 5414:	learn: 0.6157198	total: 57s	remaining: 48.3s
# 5415:	learn: 0.6157197	total: 57s	remaining: 48.3s
# 5416:	learn: 0.6157196	total: 57s	remaining: 48.3s
# 5417:	learn: 0.6157196	total: 57s	remaining: 48.2s
# 5418:	learn: 0.6157193	total: 57s	remaining: 48.2s
# 5419:	learn: 0.6157192	total: 57.1s	remaining: 48.2s
# 5420:	learn: 0.6157192	total: 57.1s	remaining: 48.2s
# 5421:	learn: 0.6157191	total: 57.1s	remaining: 48.2s
# 5422:	learn: 0.6157191	total: 57.1s	remaining: 48.2s
# 5423:	learn: 0.6157191	total: 57.1s	remaining: 48.2s
# 5424:	learn: 0.6157191	total: 57.1s	remaining: 48.2s
# 5425:	learn: 0.6157191	total: 57.1s	remaining: 48.1s
# 5426:	learn: 0.6157191	total: 57.1s	remaining: 48.1s
# 5427:	learn: 0.6157189	total: 57.1s	remaining: 48.1s
# 5428:	learn: 0.6157186	total: 57.1s	remaining: 48.1s
# 5429:	learn: 0.6157186	total: 57.1s	remaining: 48.1s
# 5430:	learn: 0.6157183	total: 57.2s	remaining: 48.1s
# 5431:	learn: 0.6157183	total: 57.2s	remaining: 48.1s
# 5432:	learn: 0.6157183	total: 57.2s	remaining: 48.1s
# 5433:	learn: 0.6157182	total: 57.2s	remaining: 48s
# 5434:	learn: 0.6157182	total: 57.2s	remaining: 48s
# 5435:	learn: 0.6157181	total: 57.2s	remaining: 48s
# 5436:	learn: 0.6157180	total: 57.2s	remaining: 48s
# 5437:	learn: 0.6157180	total: 57.2s	remaining: 48s
# 5438:	learn: 0.6157174	total: 57.2s	remaining: 48s
# 5439:	learn: 0.6157174	total: 57.2s	remaining: 48s
# 5440:	learn: 0.6157174	total: 57.2s	remaining: 48s
# 5441:	learn: 0.6157173	total: 57.2s	remaining: 47.9s
# 5442:	learn: 0.6157173	total: 57.3s	remaining: 47.9s
# 5443:	learn: 0.6157172	total: 57.3s	remaining: 47.9s
# 5444:	learn: 0.6157171	total: 57.3s	remaining: 47.9s
# 5445:	learn: 0.6157171	total: 57.3s	remaining: 47.9s
# 5446:	learn: 0.6157170	total: 57.3s	remaining: 47.9s
# 5447:	learn: 0.6157170	total: 57.3s	remaining: 47.9s
# 5448:	learn: 0.6157170	total: 57.3s	remaining: 47.9s
# 5449:	learn: 0.6157170	total: 57.3s	remaining: 47.9s
# 5450:	learn: 0.6157169	total: 57.3s	remaining: 47.8s
# 5451:	learn: 0.6157169	total: 57.3s	remaining: 47.8s
# 5452:	learn: 0.6157168	total: 57.3s	remaining: 47.8s
# 5453:	learn: 0.6157168	total: 57.4s	remaining: 47.8s
# 5454:	learn: 0.6157163	total: 57.4s	remaining: 47.8s
# 5455:	learn: 0.6157162	total: 57.4s	remaining: 47.8s
# 5456:	learn: 0.6157159	total: 57.4s	remaining: 47.8s
# 5457:	learn: 0.6157159	total: 57.4s	remaining: 47.8s
# 5458:	learn: 0.6157154	total: 57.4s	remaining: 47.8s
# 5459:	learn: 0.6157150	total: 57.4s	remaining: 47.7s
# 5460:	learn: 0.6157150	total: 57.4s	remaining: 47.7s
# 5461:	learn: 0.6157150	total: 57.4s	remaining: 47.7s
# 5462:	learn: 0.6157150	total: 57.4s	remaining: 47.7s
# 5463:	learn: 0.6157145	total: 57.4s	remaining: 47.7s
# 5464:	learn: 0.6157145	total: 57.5s	remaining: 47.7s
# 5465:	learn: 0.6157140	total: 57.5s	remaining: 47.7s
# 5466:	learn: 0.6157140	total: 57.5s	remaining: 47.7s
# 5467:	learn: 0.6157133	total: 57.5s	remaining: 47.7s
# 5468:	learn: 0.6157132	total: 57.5s	remaining: 47.7s
# 5469:	learn: 0.6157132	total: 57.5s	remaining: 47.6s
# 5470:	learn: 0.6157132	total: 57.5s	remaining: 47.6s
# 5471:	learn: 0.6157130	total: 57.5s	remaining: 47.6s
# 5472:	learn: 0.6157128	total: 57.6s	remaining: 47.6s
# 5473:	learn: 0.6157122	total: 57.6s	remaining: 47.6s
# 5474:	learn: 0.6157119	total: 57.6s	remaining: 47.6s
# 5475:	learn: 0.6157118	total: 57.6s	remaining: 47.6s
# 5476:	learn: 0.6157118	total: 57.6s	remaining: 47.6s
# 5477:	learn: 0.6157117	total: 57.6s	remaining: 47.5s
# 5478:	learn: 0.6157117	total: 57.6s	remaining: 47.5s
# 5479:	learn: 0.6157112	total: 57.6s	remaining: 47.5s
# 5480:	learn: 0.6157112	total: 57.6s	remaining: 47.5s
# 5481:	learn: 0.6157107	total: 57.6s	remaining: 47.5s
# 5482:	learn: 0.6157105	total: 57.6s	remaining: 47.5s
# 5483:	learn: 0.6157105	total: 57.7s	remaining: 47.5s
# 5484:	learn: 0.6157104	total: 57.7s	remaining: 47.5s
# 5485:	learn: 0.6157103	total: 57.7s	remaining: 47.5s
# 5486:	learn: 0.6157103	total: 57.7s	remaining: 47.5s
# 5487:	learn: 0.6157102	total: 57.7s	remaining: 47.4s
# 5488:	learn: 0.6157102	total: 57.7s	remaining: 47.4s
# 5489:	learn: 0.6157101	total: 57.7s	remaining: 47.4s
# 5490:	learn: 0.6157101	total: 57.7s	remaining: 47.4s
# 5491:	learn: 0.6157101	total: 57.7s	remaining: 47.4s
# 5492:	learn: 0.6157101	total: 57.7s	remaining: 47.4s
# 5493:	learn: 0.6157101	total: 57.8s	remaining: 47.4s
# 5494:	learn: 0.6157095	total: 57.8s	remaining: 47.4s
# 5495:	learn: 0.6157095	total: 57.8s	remaining: 47.3s
# 5496:	learn: 0.6157094	total: 57.8s	remaining: 47.3s
# 5497:	learn: 0.6157092	total: 57.8s	remaining: 47.3s
# 5498:	learn: 0.6157092	total: 57.8s	remaining: 47.3s
# 5499:	learn: 0.6157090	total: 57.8s	remaining: 47.3s
# 5500:	learn: 0.6157090	total: 57.8s	remaining: 47.3s
# 5501:	learn: 0.6157085	total: 57.8s	remaining: 47.3s
# 5502:	learn: 0.6157085	total: 57.8s	remaining: 47.3s
# 5503:	learn: 0.6157082	total: 57.8s	remaining: 47.2s
# 5504:	learn: 0.6157082	total: 57.8s	remaining: 47.2s
# 5505:	learn: 0.6157082	total: 57.9s	remaining: 47.2s
# 5506:	learn: 0.6157082	total: 57.9s	remaining: 47.2s
# 5507:	learn: 0.6157081	total: 57.9s	remaining: 47.2s
# 5508:	learn: 0.6157081	total: 57.9s	remaining: 47.2s
# 5509:	learn: 0.6157080	total: 57.9s	remaining: 47.2s
# 5510:	learn: 0.6157077	total: 57.9s	remaining: 47.2s
# 5511:	learn: 0.6157076	total: 57.9s	remaining: 47.2s
# 5512:	learn: 0.6157076	total: 57.9s	remaining: 47.1s
# 5513:	learn: 0.6157076	total: 57.9s	remaining: 47.1s
# 5514:	learn: 0.6157076	total: 57.9s	remaining: 47.1s
# 5515:	learn: 0.6157074	total: 58s	remaining: 47.1s
# 5516:	learn: 0.6157060	total: 58s	remaining: 47.1s
# 5517:	learn: 0.6157060	total: 58s	remaining: 47.1s
# 5518:	learn: 0.6157060	total: 58s	remaining: 47.1s
# 5519:	learn: 0.6157058	total: 58s	remaining: 47.1s
# 5520:	learn: 0.6157057	total: 58s	remaining: 47.1s
# 5521:	learn: 0.6157056	total: 58s	remaining: 47s
# 5522:	learn: 0.6157054	total: 58s	remaining: 47s
# 5523:	learn: 0.6157054	total: 58s	remaining: 47s
# 5524:	learn: 0.6157054	total: 58s	remaining: 47s
# 5525:	learn: 0.6157054	total: 58s	remaining: 47s
# 5526:	learn: 0.6157054	total: 58s	remaining: 47s
# 5527:	learn: 0.6157054	total: 58.1s	remaining: 47s
# 5528:	learn: 0.6157053	total: 58.1s	remaining: 47s
# 5529:	learn: 0.6157053	total: 58.1s	remaining: 46.9s
# 5530:	learn: 0.6157052	total: 58.1s	remaining: 46.9s
# 5531:	learn: 0.6157052	total: 58.1s	remaining: 46.9s
# 5532:	learn: 0.6157052	total: 58.1s	remaining: 46.9s
# 5533:	learn: 0.6157051	total: 58.1s	remaining: 46.9s
# 5534:	learn: 0.6157051	total: 58.1s	remaining: 46.9s
# 5535:	learn: 0.6157050	total: 58.1s	remaining: 46.9s
# 5536:	learn: 0.6157050	total: 58.1s	remaining: 46.9s
# 5537:	learn: 0.6157050	total: 58.1s	remaining: 46.9s
# 5538:	learn: 0.6157047	total: 58.2s	remaining: 46.8s
# 5539:	learn: 0.6157044	total: 58.2s	remaining: 46.8s
# 5540:	learn: 0.6157044	total: 58.2s	remaining: 46.8s
# 5541:	learn: 0.6157044	total: 58.2s	remaining: 46.8s
# 5542:	learn: 0.6157044	total: 58.2s	remaining: 46.8s
# 5543:	learn: 0.6157044	total: 58.2s	remaining: 46.8s
# 5544:	learn: 0.6157043	total: 58.2s	remaining: 46.8s
# 5545:	learn: 0.6157041	total: 58.2s	remaining: 46.8s
# 5546:	learn: 0.6157040	total: 58.2s	remaining: 46.7s
# 5547:	learn: 0.6157039	total: 58.2s	remaining: 46.7s
# 5548:	learn: 0.6157039	total: 58.2s	remaining: 46.7s
# 5549:	learn: 0.6157039	total: 58.2s	remaining: 46.7s
# 5550:	learn: 0.6157039	total: 58.3s	remaining: 46.7s
# 5551:	learn: 0.6157039	total: 58.3s	remaining: 46.7s
# 5552:	learn: 0.6157033	total: 58.3s	remaining: 46.7s
# 5553:	learn: 0.6157032	total: 58.3s	remaining: 46.7s
# 5554:	learn: 0.6157032	total: 58.3s	remaining: 46.6s
# 5555:	learn: 0.6157031	total: 58.3s	remaining: 46.6s
# 5556:	learn: 0.6157031	total: 58.3s	remaining: 46.6s
# 5557:	learn: 0.6157030	total: 58.3s	remaining: 46.6s
# 5558:	learn: 0.6157019	total: 58.3s	remaining: 46.6s
# 5559:	learn: 0.6157019	total: 58.3s	remaining: 46.6s
# 5560:	learn: 0.6157019	total: 58.3s	remaining: 46.6s
# 5561:	learn: 0.6157018	total: 58.4s	remaining: 46.6s
# 5562:	learn: 0.6157018	total: 58.4s	remaining: 46.6s
# 5563:	learn: 0.6157017	total: 58.4s	remaining: 46.5s
# 5564:	learn: 0.6157017	total: 58.4s	remaining: 46.5s
# 5565:	learn: 0.6157016	total: 58.4s	remaining: 46.5s
# 5566:	learn: 0.6157016	total: 58.4s	remaining: 46.5s
# 5567:	learn: 0.6157006	total: 58.4s	remaining: 46.5s
# 5568:	learn: 0.6157006	total: 58.4s	remaining: 46.5s
# 5569:	learn: 0.6157004	total: 58.4s	remaining: 46.5s
# 5570:	learn: 0.6157004	total: 58.4s	remaining: 46.5s
# 5571:	learn: 0.6157003	total: 58.4s	remaining: 46.4s
# 5572:	learn: 0.6157003	total: 58.5s	remaining: 46.4s
# 5573:	learn: 0.6157003	total: 58.5s	remaining: 46.4s
# 5574:	learn: 0.6157000	total: 58.5s	remaining: 46.4s
# 5575:	learn: 0.6156999	total: 58.5s	remaining: 46.4s
# 5576:	learn: 0.6156999	total: 58.5s	remaining: 46.4s
# 5577:	learn: 0.6156999	total: 58.5s	remaining: 46.4s
# 5578:	learn: 0.6156998	total: 58.5s	remaining: 46.4s
# 5579:	learn: 0.6156998	total: 58.5s	remaining: 46.4s
# 5580:	learn: 0.6156997	total: 58.5s	remaining: 46.4s
# 5581:	learn: 0.6156997	total: 58.6s	remaining: 46.3s
# 5582:	learn: 0.6156997	total: 58.6s	remaining: 46.3s
# 5583:	learn: 0.6156996	total: 58.6s	remaining: 46.3s
# 5584:	learn: 0.6156995	total: 58.6s	remaining: 46.3s
# 5585:	learn: 0.6156991	total: 58.6s	remaining: 46.3s
# 5586:	learn: 0.6156991	total: 58.6s	remaining: 46.3s
# 5587:	learn: 0.6156991	total: 58.6s	remaining: 46.3s
# 5588:	learn: 0.6156991	total: 58.6s	remaining: 46.3s
# 5589:	learn: 0.6156988	total: 58.6s	remaining: 46.2s
# 5590:	learn: 0.6156988	total: 58.6s	remaining: 46.2s
# 5591:	learn: 0.6156988	total: 58.6s	remaining: 46.2s
# 5592:	learn: 0.6156987	total: 58.7s	remaining: 46.2s
# 5593:	learn: 0.6156987	total: 58.7s	remaining: 46.2s
# 5594:	learn: 0.6156986	total: 58.7s	remaining: 46.2s
# 5595:	learn: 0.6156977	total: 58.7s	remaining: 46.2s
# 5596:	learn: 0.6156974	total: 58.7s	remaining: 46.2s
# 5597:	learn: 0.6156971	total: 58.7s	remaining: 46.2s
# 5598:	learn: 0.6156971	total: 58.7s	remaining: 46.1s
# 5599:	learn: 0.6156971	total: 58.7s	remaining: 46.1s
# 5600:	learn: 0.6156969	total: 58.7s	remaining: 46.1s
# 5601:	learn: 0.6156968	total: 58.7s	remaining: 46.1s
# 5602:	learn: 0.6156967	total: 58.8s	remaining: 46.1s
# 5603:	learn: 0.6156967	total: 58.8s	remaining: 46.1s
# 5604:	learn: 0.6156964	total: 58.8s	remaining: 46.1s
# 5605:	learn: 0.6156964	total: 58.8s	remaining: 46.1s
# 5606:	learn: 0.6156964	total: 58.8s	remaining: 46.1s
# 5607:	learn: 0.6156964	total: 58.8s	remaining: 46s
# 5608:	learn: 0.6156960	total: 58.8s	remaining: 46s
# 5609:	learn: 0.6156960	total: 58.8s	remaining: 46s
# 5610:	learn: 0.6156960	total: 58.8s	remaining: 46s
# 5611:	learn: 0.6156950	total: 58.8s	remaining: 46s
# 5612:	learn: 0.6156949	total: 58.8s	remaining: 46s
# 5613:	learn: 0.6156949	total: 58.8s	remaining: 46s
# 5614:	learn: 0.6156946	total: 58.8s	remaining: 46s
# 5615:	learn: 0.6156946	total: 58.9s	remaining: 45.9s
# 5616:	learn: 0.6156946	total: 58.9s	remaining: 45.9s
# 5617:	learn: 0.6156945	total: 58.9s	remaining: 45.9s
# 5618:	learn: 0.6156944	total: 58.9s	remaining: 45.9s
# 5619:	learn: 0.6156944	total: 58.9s	remaining: 45.9s
# 5620:	learn: 0.6156944	total: 58.9s	remaining: 45.9s
# 5621:	learn: 0.6156944	total: 58.9s	remaining: 45.9s
# 5622:	learn: 0.6156943	total: 58.9s	remaining: 45.9s
# 5623:	learn: 0.6156941	total: 58.9s	remaining: 45.8s
# 5624:	learn: 0.6156941	total: 58.9s	remaining: 45.8s
# 5625:	learn: 0.6156933	total: 59s	remaining: 45.8s
# 5626:	learn: 0.6156932	total: 59s	remaining: 45.8s
# 5627:	learn: 0.6156932	total: 59s	remaining: 45.8s
# 5628:	learn: 0.6156931	total: 59s	remaining: 45.8s
# 5629:	learn: 0.6156930	total: 59s	remaining: 45.8s
# 5630:	learn: 0.6156930	total: 59s	remaining: 45.8s
# 5631:	learn: 0.6156928	total: 59s	remaining: 45.8s
# 5632:	learn: 0.6156928	total: 59s	remaining: 45.8s
# 5633:	learn: 0.6156928	total: 59s	remaining: 45.7s
# 5634:	learn: 0.6156927	total: 59s	remaining: 45.7s
# 5635:	learn: 0.6156920	total: 59s	remaining: 45.7s
# 5636:	learn: 0.6156920	total: 59.1s	remaining: 45.7s
# 5637:	learn: 0.6156920	total: 59.1s	remaining: 45.7s
# 5638:	learn: 0.6156918	total: 59.1s	remaining: 45.7s
# 5639:	learn: 0.6156918	total: 59.1s	remaining: 45.7s
# 5640:	learn: 0.6156918	total: 59.1s	remaining: 45.7s
# 5641:	learn: 0.6156917	total: 59.1s	remaining: 45.6s
# 5642:	learn: 0.6156916	total: 59.1s	remaining: 45.6s
# 5643:	learn: 0.6156913	total: 59.1s	remaining: 45.6s
# 5644:	learn: 0.6156913	total: 59.1s	remaining: 45.6s
# 5645:	learn: 0.6156911	total: 59.1s	remaining: 45.6s
# 5646:	learn: 0.6156911	total: 59.1s	remaining: 45.6s
# 5647:	learn: 0.6156910	total: 59.2s	remaining: 45.6s
# 5648:	learn: 0.6156910	total: 59.2s	remaining: 45.6s
# 5649:	learn: 0.6156910	total: 59.2s	remaining: 45.6s
# 5650:	learn: 0.6156909	total: 59.2s	remaining: 45.5s
# 5651:	learn: 0.6156909	total: 59.2s	remaining: 45.5s
# 5652:	learn: 0.6156909	total: 59.2s	remaining: 45.5s
# 5653:	learn: 0.6156909	total: 59.2s	remaining: 45.5s
# 5654:	learn: 0.6156907	total: 59.2s	remaining: 45.5s
# 5655:	learn: 0.6156906	total: 59.2s	remaining: 45.5s
# 5656:	learn: 0.6156901	total: 59.2s	remaining: 45.5s
# 5657:	learn: 0.6156901	total: 59.2s	remaining: 45.5s
# 5658:	learn: 0.6156901	total: 59.3s	remaining: 45.5s
# 5659:	learn: 0.6156900	total: 59.3s	remaining: 45.4s
# 5660:	learn: 0.6156895	total: 59.3s	remaining: 45.4s
# 5661:	learn: 0.6156894	total: 59.3s	remaining: 45.4s
# 5662:	learn: 0.6156894	total: 59.3s	remaining: 45.4s
# 5663:	learn: 0.6156893	total: 59.3s	remaining: 45.4s
# 5664:	learn: 0.6156890	total: 59.3s	remaining: 45.4s
# 5665:	learn: 0.6156889	total: 59.3s	remaining: 45.4s
# 5666:	learn: 0.6156889	total: 59.3s	remaining: 45.4s
# 5667:	learn: 0.6156889	total: 59.3s	remaining: 45.3s
# 5668:	learn: 0.6156889	total: 59.3s	remaining: 45.3s
# 5669:	learn: 0.6156889	total: 59.3s	remaining: 45.3s
# 5670:	learn: 0.6156887	total: 59.4s	remaining: 45.3s
# 5671:	learn: 0.6156886	total: 59.4s	remaining: 45.3s
# 5672:	learn: 0.6156886	total: 59.4s	remaining: 45.3s
# 5673:	learn: 0.6156884	total: 59.4s	remaining: 45.3s
# 5674:	learn: 0.6156884	total: 59.4s	remaining: 45.3s
# 5675:	learn: 0.6156884	total: 59.4s	remaining: 45.3s
# 5676:	learn: 0.6156884	total: 59.4s	remaining: 45.2s
# 5677:	learn: 0.6156882	total: 59.4s	remaining: 45.2s
# 5678:	learn: 0.6156882	total: 59.4s	remaining: 45.2s
# 5679:	learn: 0.6156879	total: 59.4s	remaining: 45.2s
# 5680:	learn: 0.6156879	total: 59.5s	remaining: 45.2s
# 5681:	learn: 0.6156879	total: 59.5s	remaining: 45.2s
# 5682:	learn: 0.6156878	total: 59.5s	remaining: 45.2s
# 5683:	learn: 0.6156877	total: 59.5s	remaining: 45.2s
# 5684:	learn: 0.6156874	total: 59.5s	remaining: 45.2s
# 5685:	learn: 0.6156874	total: 59.5s	remaining: 45.1s
# 5686:	learn: 0.6156874	total: 59.5s	remaining: 45.1s
# 5687:	learn: 0.6156874	total: 59.5s	remaining: 45.1s
# 5688:	learn: 0.6156873	total: 59.5s	remaining: 45.1s
# 5689:	learn: 0.6156873	total: 59.5s	remaining: 45.1s
# 5690:	learn: 0.6156873	total: 59.6s	remaining: 45.1s
# 5691:	learn: 0.6156873	total: 59.6s	remaining: 45.1s
# 5692:	learn: 0.6156873	total: 59.6s	remaining: 45.1s
# 5693:	learn: 0.6156873	total: 59.6s	remaining: 45.1s
# 5694:	learn: 0.6156872	total: 59.6s	remaining: 45s
# 5695:	learn: 0.6156871	total: 59.6s	remaining: 45s
# 5696:	learn: 0.6156862	total: 59.6s	remaining: 45s
# 5697:	learn: 0.6156862	total: 59.6s	remaining: 45s
# 5698:	learn: 0.6156862	total: 59.6s	remaining: 45s
# 5699:	learn: 0.6156862	total: 59.6s	remaining: 45s
# 5700:	learn: 0.6156862	total: 59.6s	remaining: 45s
# 5701:	learn: 0.6156859	total: 59.7s	remaining: 45s
# 5702:	learn: 0.6156858	total: 59.7s	remaining: 45s
# 5703:	learn: 0.6156858	total: 59.7s	remaining: 44.9s
# 5704:	learn: 0.6156858	total: 59.7s	remaining: 44.9s
# 5705:	learn: 0.6156857	total: 59.7s	remaining: 44.9s
# 5706:	learn: 0.6156857	total: 59.7s	remaining: 44.9s
# 5707:	learn: 0.6156857	total: 59.7s	remaining: 44.9s
# 5708:	learn: 0.6156855	total: 59.7s	remaining: 44.9s
# 5709:	learn: 0.6156855	total: 59.7s	remaining: 44.9s
# 5710:	learn: 0.6156855	total: 59.7s	remaining: 44.9s
# 5711:	learn: 0.6156854	total: 59.7s	remaining: 44.8s
# 5712:	learn: 0.6156852	total: 59.8s	remaining: 44.8s
# 5713:	learn: 0.6156852	total: 59.8s	remaining: 44.8s
# 5714:	learn: 0.6156852	total: 59.8s	remaining: 44.8s
# 5715:	learn: 0.6156852	total: 59.8s	remaining: 44.8s
# 5716:	learn: 0.6156851	total: 59.8s	remaining: 44.8s
# 5717:	learn: 0.6156851	total: 59.8s	remaining: 44.8s
# 5718:	learn: 0.6156850	total: 59.8s	remaining: 44.8s
# 5719:	learn: 0.6156849	total: 59.8s	remaining: 44.8s
# 5720:	learn: 0.6156849	total: 59.8s	remaining: 44.7s
# 5721:	learn: 0.6156848	total: 59.8s	remaining: 44.7s
# 5722:	learn: 0.6156839	total: 59.8s	remaining: 44.7s
# 5723:	learn: 0.6156839	total: 59.8s	remaining: 44.7s
# 5724:	learn: 0.6156835	total: 59.9s	remaining: 44.7s
# 5725:	learn: 0.6156835	total: 59.9s	remaining: 44.7s
# 5726:	learn: 0.6156828	total: 59.9s	remaining: 44.7s
# 5727:	learn: 0.6156828	total: 59.9s	remaining: 44.7s
# 5728:	learn: 0.6156827	total: 59.9s	remaining: 44.6s
# 5729:	learn: 0.6156826	total: 59.9s	remaining: 44.6s
# 5730:	learn: 0.6156826	total: 59.9s	remaining: 44.6s
# 5731:	learn: 0.6156826	total: 59.9s	remaining: 44.6s
# 5732:	learn: 0.6156826	total: 59.9s	remaining: 44.6s
# 5733:	learn: 0.6156826	total: 59.9s	remaining: 44.6s
# 5734:	learn: 0.6156825	total: 59.9s	remaining: 44.6s
# 5735:	learn: 0.6156823	total: 59.9s	remaining: 44.6s
# 5736:	learn: 0.6156823	total: 60s	remaining: 44.5s
# 5737:	learn: 0.6156823	total: 60s	remaining: 44.5s
# 5738:	learn: 0.6156823	total: 60s	remaining: 44.5s
# 5739:	learn: 0.6156823	total: 60s	remaining: 44.5s
# 5740:	learn: 0.6156823	total: 60s	remaining: 44.5s
# 5741:	learn: 0.6156815	total: 1m	remaining: 44.5s
# 5742:	learn: 0.6156814	total: 1m	remaining: 44.5s
# 5743:	learn: 0.6156810	total: 1m	remaining: 44.5s
# 5744:	learn: 0.6156810	total: 1m	remaining: 44.5s
# 5745:	learn: 0.6156810	total: 1m	remaining: 44.5s
# 5746:	learn: 0.6156807	total: 1m	remaining: 44.4s
# 5747:	learn: 0.6156806	total: 1m	remaining: 44.4s
# 5748:	learn: 0.6156805	total: 1m	remaining: 44.4s
# 5749:	learn: 0.6156805	total: 1m	remaining: 44.4s
# 5750:	learn: 0.6156804	total: 1m	remaining: 44.4s
# 5751:	learn: 0.6156803	total: 1m	remaining: 44.4s
# 5752:	learn: 0.6156803	total: 1m	remaining: 44.4s
# 5753:	learn: 0.6156803	total: 1m	remaining: 44.4s
# 5754:	learn: 0.6156802	total: 1m	remaining: 44.3s
# 5755:	learn: 0.6156802	total: 1m	remaining: 44.3s
# 5756:	learn: 0.6156802	total: 1m	remaining: 44.3s
# 5757:	learn: 0.6156802	total: 1m	remaining: 44.3s
# 5758:	learn: 0.6156801	total: 1m	remaining: 44.3s
# 5759:	learn: 0.6156801	total: 1m	remaining: 44.3s
# 5760:	learn: 0.6156801	total: 1m	remaining: 44.3s
# 5761:	learn: 0.6156801	total: 1m	remaining: 44.3s
# 5762:	learn: 0.6156801	total: 1m	remaining: 44.3s
# 5763:	learn: 0.6156800	total: 1m	remaining: 44.2s
# 5764:	learn: 0.6156800	total: 1m	remaining: 44.2s
# 5765:	learn: 0.6156800	total: 1m	remaining: 44.2s
# 5766:	learn: 0.6156799	total: 1m	remaining: 44.2s
# 5767:	learn: 0.6156798	total: 1m	remaining: 44.2s
# 5768:	learn: 0.6156797	total: 1m	remaining: 44.2s
# 5769:	learn: 0.6156797	total: 1m	remaining: 44.2s
# 5770:	learn: 0.6156797	total: 1m	remaining: 44.2s
# 5771:	learn: 0.6156796	total: 1m	remaining: 44.1s
# 5772:	learn: 0.6156796	total: 1m	remaining: 44.1s
# 5773:	learn: 0.6156793	total: 1m	remaining: 44.1s
# 5774:	learn: 0.6156793	total: 1m	remaining: 44.1s
# 5775:	learn: 0.6156793	total: 1m	remaining: 44.1s
# 5776:	learn: 0.6156792	total: 1m	remaining: 44.1s
# 5777:	learn: 0.6156792	total: 1m	remaining: 44.1s
# 5778:	learn: 0.6156791	total: 1m	remaining: 44.1s
# 5779:	learn: 0.6156791	total: 1m	remaining: 44.1s
# 5780:	learn: 0.6156789	total: 1m	remaining: 44s
# 5781:	learn: 0.6156788	total: 1m	remaining: 44s
# 5782:	learn: 0.6156787	total: 1m	remaining: 44s
# 5783:	learn: 0.6156787	total: 1m	remaining: 44s
# 5784:	learn: 0.6156787	total: 1m	remaining: 44s
# 5785:	learn: 0.6156787	total: 1m	remaining: 44s
# 5786:	learn: 0.6156787	total: 1m	remaining: 44s
# 5787:	learn: 0.6156787	total: 1m	remaining: 44s
# 5788:	learn: 0.6156787	total: 1m	remaining: 44s
# 5789:	learn: 0.6156787	total: 1m	remaining: 43.9s
# 5790:	learn: 0.6156787	total: 1m	remaining: 43.9s
# 5791:	learn: 0.6156787	total: 1m	remaining: 43.9s
# 5792:	learn: 0.6156786	total: 1m	remaining: 43.9s
# 5793:	learn: 0.6156785	total: 1m	remaining: 43.9s
# 5794:	learn: 0.6156785	total: 1m	remaining: 43.9s
# 5795:	learn: 0.6156785	total: 1m	remaining: 43.9s
# 5796:	learn: 0.6156779	total: 1m	remaining: 43.9s
# 5797:	learn: 0.6156779	total: 1m	remaining: 43.9s
# 5798:	learn: 0.6156778	total: 1m	remaining: 43.8s
# 5799:	learn: 0.6156775	total: 1m	remaining: 43.8s
# 5800:	learn: 0.6156773	total: 1m	remaining: 43.8s
# 5801:	learn: 0.6156773	total: 1m	remaining: 43.8s
# 5802:	learn: 0.6156773	total: 1m	remaining: 43.8s
# 5803:	learn: 0.6156772	total: 1m	remaining: 43.8s
# 5804:	learn: 0.6156772	total: 1m	remaining: 43.8s
# 5805:	learn: 0.6156772	total: 1m	remaining: 43.8s
# 5806:	learn: 0.6156772	total: 1m	remaining: 43.8s
# 5807:	learn: 0.6156772	total: 1m	remaining: 43.7s
# 5808:	learn: 0.6156771	total: 1m	remaining: 43.7s
# 5809:	learn: 0.6156768	total: 1m	remaining: 43.7s
# 5810:	learn: 0.6156768	total: 1m	remaining: 43.7s
# 5811:	learn: 0.6156768	total: 1m	remaining: 43.7s
# 5812:	learn: 0.6156768	total: 1m	remaining: 43.7s
# 5813:	learn: 0.6156768	total: 1m	remaining: 43.7s
# 5814:	learn: 0.6156767	total: 1m	remaining: 43.7s
# 5815:	learn: 0.6156767	total: 1m	remaining: 43.7s
# 5816:	learn: 0.6156767	total: 1m	remaining: 43.6s
# 5817:	learn: 0.6156767	total: 1m	remaining: 43.6s
# 5818:	learn: 0.6156767	total: 1m	remaining: 43.6s
# 5819:	learn: 0.6156767	total: 1m	remaining: 43.6s
# 5820:	learn: 0.6156766	total: 1m	remaining: 43.6s
# 5821:	learn: 0.6156766	total: 1m	remaining: 43.6s
# 5822:	learn: 0.6156765	total: 1m	remaining: 43.6s
# 5823:	learn: 0.6156764	total: 1m	remaining: 43.6s
# 5824:	learn: 0.6156764	total: 1m	remaining: 43.5s
# 5825:	learn: 0.6156764	total: 1m	remaining: 43.5s
# 5826:	learn: 0.6156763	total: 1m	remaining: 43.5s
# 5827:	learn: 0.6156763	total: 1m	remaining: 43.5s
# 5828:	learn: 0.6156763	total: 1m	remaining: 43.5s
# 5829:	learn: 0.6156763	total: 1m	remaining: 43.5s
# 5830:	learn: 0.6156761	total: 1m	remaining: 43.5s
# 5831:	learn: 0.6156761	total: 1m	remaining: 43.5s
# 5832:	learn: 0.6156761	total: 1m	remaining: 43.5s
# 5833:	learn: 0.6156761	total: 1m	remaining: 43.4s
# 5834:	learn: 0.6156761	total: 1m	remaining: 43.4s
# 5835:	learn: 0.6156761	total: 1m	remaining: 43.4s
# 5836:	learn: 0.6156761	total: 1m	remaining: 43.4s
# 5837:	learn: 0.6156760	total: 1m	remaining: 43.4s
# 5838:	learn: 0.6156759	total: 1m	remaining: 43.4s
# 5839:	learn: 0.6156759	total: 1m	remaining: 43.4s
# 5840:	learn: 0.6156759	total: 1m	remaining: 43.4s
# 5841:	learn: 0.6156758	total: 1m	remaining: 43.3s
# 5842:	learn: 0.6156758	total: 1m	remaining: 43.3s
# 5843:	learn: 0.6156757	total: 1m	remaining: 43.3s
# 5844:	learn: 0.6156757	total: 1m	remaining: 43.3s
# 5845:	learn: 0.6156757	total: 1m	remaining: 43.3s
# 5846:	learn: 0.6156757	total: 1m	remaining: 43.3s
# 5847:	learn: 0.6156757	total: 1m	remaining: 43.3s
# 5848:	learn: 0.6156757	total: 1m	remaining: 43.3s
# 5849:	learn: 0.6156756	total: 1m	remaining: 43.3s
# 5850:	learn: 0.6156756	total: 1m	remaining: 43.2s
# 5851:	learn: 0.6156754	total: 1m	remaining: 43.2s
# 5852:	learn: 0.6156753	total: 1m 1s	remaining: 43.2s
# 5853:	learn: 0.6156753	total: 1m 1s	remaining: 43.2s
# 5854:	learn: 0.6156752	total: 1m 1s	remaining: 43.2s
# 5855:	learn: 0.6156751	total: 1m 1s	remaining: 43.2s
# 5856:	learn: 0.6156751	total: 1m 1s	remaining: 43.2s
# 5857:	learn: 0.6156751	total: 1m 1s	remaining: 43.2s
# 5858:	learn: 0.6156748	total: 1m 1s	remaining: 43.2s
# 5859:	learn: 0.6156745	total: 1m 1s	remaining: 43.1s
# 5860:	learn: 0.6156744	total: 1m 1s	remaining: 43.1s
# 5861:	learn: 0.6156744	total: 1m 1s	remaining: 43.1s
# 5862:	learn: 0.6156743	total: 1m 1s	remaining: 43.1s
# 5863:	learn: 0.6156742	total: 1m 1s	remaining: 43.1s
# 5864:	learn: 0.6156742	total: 1m 1s	remaining: 43.1s
# 5865:	learn: 0.6156729	total: 1m 1s	remaining: 43.1s
# 5866:	learn: 0.6156729	total: 1m 1s	remaining: 43.1s
# 5867:	learn: 0.6156729	total: 1m 1s	remaining: 43s
# 5868:	learn: 0.6156729	total: 1m 1s	remaining: 43s
# 5869:	learn: 0.6156724	total: 1m 1s	remaining: 43s
# 5870:	learn: 0.6156724	total: 1m 1s	remaining: 43s
# 5871:	learn: 0.6156722	total: 1m 1s	remaining: 43s
# 5872:	learn: 0.6156722	total: 1m 1s	remaining: 43s
# 5873:	learn: 0.6156722	total: 1m 1s	remaining: 43s
# 5874:	learn: 0.6156721	total: 1m 1s	remaining: 43s
# 5875:	learn: 0.6156721	total: 1m 1s	remaining: 43s
# 5876:	learn: 0.6156721	total: 1m 1s	remaining: 43s
# 5877:	learn: 0.6156719	total: 1m 1s	remaining: 43s
# 5878:	learn: 0.6156719	total: 1m 1s	remaining: 43s
# 5879:	learn: 0.6156710	total: 1m 1s	remaining: 43s
# 5880:	learn: 0.6156710	total: 1m 1s	remaining: 42.9s
# 5881:	learn: 0.6156709	total: 1m 1s	remaining: 42.9s
# 5882:	learn: 0.6156709	total: 1m 1s	remaining: 42.9s
# 5883:	learn: 0.6156709	total: 1m 1s	remaining: 42.9s
# 5884:	learn: 0.6156709	total: 1m 1s	remaining: 42.9s
# 5885:	learn: 0.6156709	total: 1m 1s	remaining: 42.9s
# 5886:	learn: 0.6156708	total: 1m 1s	remaining: 42.9s
# 5887:	learn: 0.6156707	total: 1m 1s	remaining: 42.9s
# 5888:	learn: 0.6156706	total: 1m 1s	remaining: 42.9s
# 5889:	learn: 0.6156705	total: 1m 1s	remaining: 42.9s
# 5890:	learn: 0.6156704	total: 1m 1s	remaining: 42.9s
# 5891:	learn: 0.6156703	total: 1m 1s	remaining: 42.9s
# 5892:	learn: 0.6156703	total: 1m 1s	remaining: 42.9s
# 5893:	learn: 0.6156703	total: 1m 1s	remaining: 42.8s
# 5894:	learn: 0.6156698	total: 1m 1s	remaining: 42.8s
# 5895:	learn: 0.6156698	total: 1m 1s	remaining: 42.8s
# 5896:	learn: 0.6156698	total: 1m 1s	remaining: 42.8s
# 5897:	learn: 0.6156698	total: 1m 1s	remaining: 42.8s
# 5898:	learn: 0.6156697	total: 1m 1s	remaining: 42.8s
# 5899:	learn: 0.6156697	total: 1m 1s	remaining: 42.8s
# 5900:	learn: 0.6156697	total: 1m 1s	remaining: 42.8s
# 5901:	learn: 0.6156697	total: 1m 1s	remaining: 42.8s
# 5902:	learn: 0.6156697	total: 1m 1s	remaining: 42.8s
# 5903:	learn: 0.6156697	total: 1m 1s	remaining: 42.8s
# 5904:	learn: 0.6156696	total: 1m 1s	remaining: 42.7s
# 5905:	learn: 0.6156696	total: 1m 1s	remaining: 42.7s
# 5906:	learn: 0.6156696	total: 1m 1s	remaining: 42.7s
# 5907:	learn: 0.6156695	total: 1m 1s	remaining: 42.7s
# 5908:	learn: 0.6156695	total: 1m 1s	remaining: 42.7s
# 5909:	learn: 0.6156695	total: 1m 1s	remaining: 42.7s
# 5910:	learn: 0.6156695	total: 1m 1s	remaining: 42.7s
# 5911:	learn: 0.6156694	total: 1m 1s	remaining: 42.7s
# 5912:	learn: 0.6156694	total: 1m 1s	remaining: 42.7s
# 5913:	learn: 0.6156694	total: 1m 1s	remaining: 42.7s
# 5914:	learn: 0.6156692	total: 1m 1s	remaining: 42.7s
# 5915:	learn: 0.6156689	total: 1m 1s	remaining: 42.7s
# 5916:	learn: 0.6156688	total: 1m 1s	remaining: 42.7s
# ...
# 9726:	learn: 0.6154920	total: 1m 42s	remaining: 2.87s
# 9727:	learn: 0.6154920	total: 1m 42s	remaining: 2.86s
# 9728:	learn: 0.6154920	total: 1m 42s	remaining: 2.85s
# 9729:	learn: 0.6154920	total: 1m 42s	remaining: 2.84s
# 9730:	learn: 0.6154920	total: 1m 42s	remaining: 2.83s
# 9731:	learn: 0.6154920	total: 1m 42s	remaining: 2.82s
# 9732:	learn: 0.6154919	total: 1m 42s	remaining: 2.81s
# 9733:	learn: 0.6154919	total: 1m 42s	remaining: 2.8s
# 9734:	learn: 0.6154919	total: 1m 42s	remaining: 2.79s
# 9735:	learn: 0.6154916	total: 1m 42s	remaining: 2.78s
# 9736:	learn: 0.6154916	total: 1m 42s	remaining: 2.77s
# 9737:	learn: 0.6154916	total: 1m 42s	remaining: 2.76s
# 9738:	learn: 0.6154916	total: 1m 42s	remaining: 2.75s
# 9739:	learn: 0.6154916	total: 1m 42s	remaining: 2.74s
# 9740:	learn: 0.6154915	total: 1m 42s	remaining: 2.73s
# 9741:	learn: 0.6154915	total: 1m 42s	remaining: 2.71s
# 9742:	learn: 0.6154915	total: 1m 42s	remaining: 2.71s
# 9743:	learn: 0.6154915	total: 1m 42s	remaining: 2.69s
# 9744:	learn: 0.6154915	total: 1m 42s	remaining: 2.68s
# 9745:	learn: 0.6154915	total: 1m 42s	remaining: 2.67s
# 9746:	learn: 0.6154915	total: 1m 42s	remaining: 2.66s
# 9747:	learn: 0.6154915	total: 1m 42s	remaining: 2.65s
# 9748:	learn: 0.6154914	total: 1m 42s	remaining: 2.64s
# 9749:	learn: 0.6154907	total: 1m 42s	remaining: 2.63s
# 9750:	learn: 0.6154907	total: 1m 42s	remaining: 2.62s
# 9751:	learn: 0.6154907	total: 1m 42s	remaining: 2.61s
# 9752:	learn: 0.6154907	total: 1m 42s	remaining: 2.6s
# 9753:	learn: 0.6154907	total: 1m 42s	remaining: 2.59s
# 9754:	learn: 0.6154907	total: 1m 42s	remaining: 2.58s
# 9755:	learn: 0.6154907	total: 1m 42s	remaining: 2.57s
# 9756:	learn: 0.6154907	total: 1m 42s	remaining: 2.56s
# 9757:	learn: 0.6154907	total: 1m 42s	remaining: 2.55s
# 9758:	learn: 0.6154907	total: 1m 42s	remaining: 2.54s
# 9759:	learn: 0.6154907	total: 1m 42s	remaining: 2.52s
# 9760:	learn: 0.6154907	total: 1m 42s	remaining: 2.51s
# 9761:	learn: 0.6154907	total: 1m 42s	remaining: 2.5s
# 9762:	learn: 0.6154907	total: 1m 42s	remaining: 2.49s
# 9763:	learn: 0.6154906	total: 1m 42s	remaining: 2.48s
# 9764:	learn: 0.6154906	total: 1m 42s	remaining: 2.47s
# 9765:	learn: 0.6154906	total: 1m 42s	remaining: 2.46s
# 9766:	learn: 0.6154905	total: 1m 42s	remaining: 2.45s
# 9767:	learn: 0.6154905	total: 1m 42s	remaining: 2.44s
# 9768:	learn: 0.6154905	total: 1m 42s	remaining: 2.43s
# 9769:	learn: 0.6154905	total: 1m 42s	remaining: 2.42s
# 9770:	learn: 0.6154904	total: 1m 42s	remaining: 2.41s
# 9771:	learn: 0.6154904	total: 1m 42s	remaining: 2.4s
# 9772:	learn: 0.6154904	total: 1m 42s	remaining: 2.39s
# 9773:	learn: 0.6154904	total: 1m 42s	remaining: 2.38s
# 9774:	learn: 0.6154902	total: 1m 42s	remaining: 2.37s
# 9775:	learn: 0.6154902	total: 1m 42s	remaining: 2.36s
# 9776:	learn: 0.6154902	total: 1m 42s	remaining: 2.35s
# 9777:	learn: 0.6154902	total: 1m 42s	remaining: 2.33s
# 9778:	learn: 0.6154902	total: 1m 42s	remaining: 2.33s
# 9779:	learn: 0.6154902	total: 1m 42s	remaining: 2.31s
# 9780:	learn: 0.6154901	total: 1m 42s	remaining: 2.3s
# 9781:	learn: 0.6154901	total: 1m 42s	remaining: 2.29s
# 9782:	learn: 0.6154901	total: 1m 42s	remaining: 2.28s
# 9783:	learn: 0.6154901	total: 1m 42s	remaining: 2.27s
# 9784:	learn: 0.6154901	total: 1m 42s	remaining: 2.26s
# 9785:	learn: 0.6154899	total: 1m 42s	remaining: 2.25s
# 9786:	learn: 0.6154899	total: 1m 42s	remaining: 2.24s
# 9787:	learn: 0.6154899	total: 1m 42s	remaining: 2.23s
# 9788:	learn: 0.6154899	total: 1m 42s	remaining: 2.22s
# 9789:	learn: 0.6154899	total: 1m 42s	remaining: 2.21s
# 9790:	learn: 0.6154899	total: 1m 42s	remaining: 2.2s
# 9791:	learn: 0.6154899	total: 1m 43s	remaining: 2.19s
# 9792:	learn: 0.6154899	total: 1m 43s	remaining: 2.18s
# 9793:	learn: 0.6154899	total: 1m 43s	remaining: 2.17s
# 9794:	learn: 0.6154899	total: 1m 43s	remaining: 2.16s
# 9795:	learn: 0.6154899	total: 1m 43s	remaining: 2.15s
# 9796:	learn: 0.6154899	total: 1m 43s	remaining: 2.13s
# 9797:	learn: 0.6154899	total: 1m 43s	remaining: 2.12s
# 9798:	learn: 0.6154899	total: 1m 43s	remaining: 2.11s
# 9799:	learn: 0.6154899	total: 1m 43s	remaining: 2.1s
# 9800:	learn: 0.6154899	total: 1m 43s	remaining: 2.09s
# 9801:	learn: 0.6154899	total: 1m 43s	remaining: 2.08s
# 9802:	learn: 0.6154898	total: 1m 43s	remaining: 2.07s
# 9803:	learn: 0.6154898	total: 1m 43s	remaining: 2.06s
# 9804:	learn: 0.6154897	total: 1m 43s	remaining: 2.05s
# 9805:	learn: 0.6154895	total: 1m 43s	remaining: 2.04s
# 9806:	learn: 0.6154894	total: 1m 43s	remaining: 2.03s
# 9807:	learn: 0.6154894	total: 1m 43s	remaining: 2.02s
# 9808:	learn: 0.6154893	total: 1m 43s	remaining: 2.01s
# 9809:	learn: 0.6154893	total: 1m 43s	remaining: 2s
# 9810:	learn: 0.6154893	total: 1m 43s	remaining: 1.99s
# 9811:	learn: 0.6154892	total: 1m 43s	remaining: 1.98s
# 9812:	learn: 0.6154891	total: 1m 43s	remaining: 1.97s
# 9813:	learn: 0.6154891	total: 1m 43s	remaining: 1.96s
# 9814:	learn: 0.6154891	total: 1m 43s	remaining: 1.95s
# 9815:	learn: 0.6154891	total: 1m 43s	remaining: 1.93s
# 9816:	learn: 0.6154891	total: 1m 43s	remaining: 1.92s
# 9817:	learn: 0.6154891	total: 1m 43s	remaining: 1.91s
# 9818:	learn: 0.6154891	total: 1m 43s	remaining: 1.9s
# 9819:	learn: 0.6154891	total: 1m 43s	remaining: 1.89s
# 9820:	learn: 0.6154891	total: 1m 43s	remaining: 1.88s
# 9821:	learn: 0.6154890	total: 1m 43s	remaining: 1.87s
# 9822:	learn: 0.6154890	total: 1m 43s	remaining: 1.86s
# 9823:	learn: 0.6154890	total: 1m 43s	remaining: 1.85s
# 9824:	learn: 0.6154890	total: 1m 43s	remaining: 1.84s
# 9825:	learn: 0.6154887	total: 1m 43s	remaining: 1.83s
# 9826:	learn: 0.6154887	total: 1m 43s	remaining: 1.82s
# 9827:	learn: 0.6154887	total: 1m 43s	remaining: 1.81s
# 9828:	learn: 0.6154887	total: 1m 43s	remaining: 1.8s
# 9829:	learn: 0.6154887	total: 1m 43s	remaining: 1.79s
# 9830:	learn: 0.6154887	total: 1m 43s	remaining: 1.78s
# 9831:	learn: 0.6154887	total: 1m 43s	remaining: 1.77s
# 9832:	learn: 0.6154887	total: 1m 43s	remaining: 1.75s
# 9833:	learn: 0.6154886	total: 1m 43s	remaining: 1.75s
# 9834:	learn: 0.6154885	total: 1m 43s	remaining: 1.73s
# 9835:	learn: 0.6154885	total: 1m 43s	remaining: 1.72s
# 9836:	learn: 0.6154885	total: 1m 43s	remaining: 1.71s
# 9837:	learn: 0.6154885	total: 1m 43s	remaining: 1.7s
# 9838:	learn: 0.6154885	total: 1m 43s	remaining: 1.69s
# 9839:	learn: 0.6154885	total: 1m 43s	remaining: 1.68s
# 9840:	learn: 0.6154884	total: 1m 43s	remaining: 1.67s
# 9841:	learn: 0.6154884	total: 1m 43s	remaining: 1.66s
# 9842:	learn: 0.6154884	total: 1m 43s	remaining: 1.65s
# 9843:	learn: 0.6154880	total: 1m 43s	remaining: 1.64s
# 9844:	learn: 0.6154880	total: 1m 43s	remaining: 1.63s
# 9845:	learn: 0.6154880	total: 1m 43s	remaining: 1.62s
# 9846:	learn: 0.6154880	total: 1m 43s	remaining: 1.61s
# 9847:	learn: 0.6154880	total: 1m 43s	remaining: 1.6s
# 9848:	learn: 0.6154880	total: 1m 43s	remaining: 1.59s
# 9849:	learn: 0.6154880	total: 1m 43s	remaining: 1.58s
# 9850:	learn: 0.6154880	total: 1m 43s	remaining: 1.57s
# 9851:	learn: 0.6154878	total: 1m 43s	remaining: 1.55s
# 9852:	learn: 0.6154878	total: 1m 43s	remaining: 1.54s
# 9853:	learn: 0.6154878	total: 1m 43s	remaining: 1.53s
# 9854:	learn: 0.6154878	total: 1m 43s	remaining: 1.52s
# 9855:	learn: 0.6154878	total: 1m 43s	remaining: 1.51s
# 9856:	learn: 0.6154878	total: 1m 43s	remaining: 1.5s
# 9857:	learn: 0.6154877	total: 1m 43s	remaining: 1.49s
# 9858:	learn: 0.6154877	total: 1m 43s	remaining: 1.48s
# 9859:	learn: 0.6154877	total: 1m 43s	remaining: 1.47s
# 9860:	learn: 0.6154877	total: 1m 43s	remaining: 1.46s
# 9861:	learn: 0.6154877	total: 1m 43s	remaining: 1.45s
# 9862:	learn: 0.6154877	total: 1m 43s	remaining: 1.44s
# 9863:	learn: 0.6154877	total: 1m 43s	remaining: 1.43s
# 9864:	learn: 0.6154876	total: 1m 43s	remaining: 1.42s
# 9865:	learn: 0.6154876	total: 1m 43s	remaining: 1.41s
# 9866:	learn: 0.6154876	total: 1m 43s	remaining: 1.4s
# 9867:	learn: 0.6154876	total: 1m 43s	remaining: 1.39s
# 9868:	learn: 0.6154876	total: 1m 43s	remaining: 1.38s
# 9869:	learn: 0.6154876	total: 1m 43s	remaining: 1.37s
# 9870:	learn: 0.6154876	total: 1m 43s	remaining: 1.35s
# 9871:	learn: 0.6154875	total: 1m 43s	remaining: 1.34s
# 9872:	learn: 0.6154874	total: 1m 43s	remaining: 1.33s
# 9873:	learn: 0.6154874	total: 1m 43s	remaining: 1.32s
# 9874:	learn: 0.6154873	total: 1m 43s	remaining: 1.31s
# 9875:	learn: 0.6154873	total: 1m 43s	remaining: 1.3s
# 9876:	learn: 0.6154873	total: 1m 43s	remaining: 1.29s
# 9877:	learn: 0.6154873	total: 1m 43s	remaining: 1.28s
# 9878:	learn: 0.6154872	total: 1m 43s	remaining: 1.27s
# 9879:	learn: 0.6154872	total: 1m 43s	remaining: 1.26s
# 9880:	learn: 0.6154871	total: 1m 43s	remaining: 1.25s
# 9881:	learn: 0.6154871	total: 1m 43s	remaining: 1.24s
# 9882:	learn: 0.6154871	total: 1m 43s	remaining: 1.23s
# 9883:	learn: 0.6154871	total: 1m 43s	remaining: 1.22s
# 9884:	learn: 0.6154870	total: 1m 43s	remaining: 1.21s
# 9885:	learn: 0.6154870	total: 1m 43s	remaining: 1.2s
# 9886:	learn: 0.6154870	total: 1m 43s	remaining: 1.19s
# 9887:	learn: 0.6154870	total: 1m 43s	remaining: 1.18s
# 9888:	learn: 0.6154869	total: 1m 43s	remaining: 1.17s
# 9889:	learn: 0.6154869	total: 1m 43s	remaining: 1.16s
# 9890:	learn: 0.6154869	total: 1m 43s	remaining: 1.15s
# 9891:	learn: 0.6154869	total: 1m 43s	remaining: 1.13s
# 9892:	learn: 0.6154869	total: 1m 43s	remaining: 1.12s
# 9893:	learn: 0.6154869	total: 1m 43s	remaining: 1.11s
# 9894:	learn: 0.6154869	total: 1m 43s	remaining: 1.1s
# 9895:	learn: 0.6154869	total: 1m 43s	remaining: 1.09s
# 9896:	learn: 0.6154869	total: 1m 43s	remaining: 1.08s
# 9897:	learn: 0.6154869	total: 1m 44s	remaining: 1.07s
# 9898:	learn: 0.6154869	total: 1m 44s	remaining: 1.06s
# 9899:	learn: 0.6154868	total: 1m 44s	remaining: 1.05s
# 9900:	learn: 0.6154866	total: 1m 44s	remaining: 1.04s
# 9901:	learn: 0.6154866	total: 1m 44s	remaining: 1.03s
# 9902:	learn: 0.6154866	total: 1m 44s	remaining: 1.02s
# 9903:	learn: 0.6154859	total: 1m 44s	remaining: 1.01s
# 9904:	learn: 0.6154859	total: 1m 44s	remaining: 998ms
# 9905:	learn: 0.6154859	total: 1m 44s	remaining: 988ms
# 9906:	learn: 0.6154859	total: 1m 44s	remaining: 977ms
# 9907:	learn: 0.6154858	total: 1m 44s	remaining: 966ms
# 9908:	learn: 0.6154858	total: 1m 44s	remaining: 956ms
# 9909:	learn: 0.6154856	total: 1m 44s	remaining: 945ms
# 9910:	learn: 0.6154856	total: 1m 44s	remaining: 935ms
# 9911:	learn: 0.6154855	total: 1m 44s	remaining: 924ms
# 9912:	learn: 0.6154855	total: 1m 44s	remaining: 914ms
# 9913:	learn: 0.6154855	total: 1m 44s	remaining: 903ms
# 9914:	learn: 0.6154855	total: 1m 44s	remaining: 893ms
# 9915:	learn: 0.6154855	total: 1m 44s	remaining: 882ms
# 9916:	learn: 0.6154855	total: 1m 44s	remaining: 872ms
# 9917:	learn: 0.6154854	total: 1m 44s	remaining: 861ms
# 9918:	learn: 0.6154854	total: 1m 44s	remaining: 851ms
# 9919:	learn: 0.6154854	total: 1m 44s	remaining: 840ms
# 9920:	learn: 0.6154854	total: 1m 44s	remaining: 830ms
# 9921:	learn: 0.6154854	total: 1m 44s	remaining: 819ms
# 9922:	learn: 0.6154854	total: 1m 44s	remaining: 809ms
# 9923:	learn: 0.6154854	total: 1m 44s	remaining: 798ms
# 9924:	learn: 0.6154853	total: 1m 44s	remaining: 788ms
# 9925:	learn: 0.6154853	total: 1m 44s	remaining: 777ms
# 9926:	learn: 0.6154853	total: 1m 44s	remaining: 767ms
# 9927:	learn: 0.6154853	total: 1m 44s	remaining: 756ms
# 9928:	learn: 0.6154853	total: 1m 44s	remaining: 746ms
# 9929:	learn: 0.6154853	total: 1m 44s	remaining: 735ms
# 9930:	learn: 0.6154850	total: 1m 44s	remaining: 725ms
# 9931:	learn: 0.6154850	total: 1m 44s	remaining: 714ms
# 9932:	learn: 0.6154850	total: 1m 44s	remaining: 704ms
# 9933:	learn: 0.6154850	total: 1m 44s	remaining: 693ms
# 9934:	learn: 0.6154850	total: 1m 44s	remaining: 683ms
# 9935:	learn: 0.6154849	total: 1m 44s	remaining: 672ms
# 9936:	learn: 0.6154849	total: 1m 44s	remaining: 662ms
# 9937:	learn: 0.6154849	total: 1m 44s	remaining: 651ms
# 9938:	learn: 0.6154849	total: 1m 44s	remaining: 641ms
# 9939:	learn: 0.6154849	total: 1m 44s	remaining: 630ms
# 9940:	learn: 0.6154849	total: 1m 44s	remaining: 620ms
# 9941:	learn: 0.6154849	total: 1m 44s	remaining: 609ms
# 9942:	learn: 0.6154849	total: 1m 44s	remaining: 599ms
# 9943:	learn: 0.6154849	total: 1m 44s	remaining: 588ms
# 9944:	learn: 0.6154847	total: 1m 44s	remaining: 578ms
# 9945:	learn: 0.6154847	total: 1m 44s	remaining: 567ms
# 9946:	learn: 0.6154847	total: 1m 44s	remaining: 557ms
# 9947:	learn: 0.6154847	total: 1m 44s	remaining: 546ms
# 9948:	learn: 0.6154847	total: 1m 44s	remaining: 535ms
# 9949:	learn: 0.6154847	total: 1m 44s	remaining: 525ms
# 9950:	learn: 0.6154846	total: 1m 44s	remaining: 514ms
# 9951:	learn: 0.6154846	total: 1m 44s	remaining: 504ms
# 9952:	learn: 0.6154846	total: 1m 44s	remaining: 493ms
# 9953:	learn: 0.6154846	total: 1m 44s	remaining: 483ms
# 9954:	learn: 0.6154846	total: 1m 44s	remaining: 472ms
# 9955:	learn: 0.6154846	total: 1m 44s	remaining: 462ms
# 9956:	learn: 0.6154846	total: 1m 44s	remaining: 451ms
# 9957:	learn: 0.6154846	total: 1m 44s	remaining: 441ms
# 9958:	learn: 0.6154846	total: 1m 44s	remaining: 430ms
# 9959:	learn: 0.6154846	total: 1m 44s	remaining: 420ms
# 9960:	learn: 0.6154846	total: 1m 44s	remaining: 409ms
# 9961:	learn: 0.6154846	total: 1m 44s	remaining: 399ms
# 9962:	learn: 0.6154846	total: 1m 44s	remaining: 388ms
# 9963:	learn: 0.6154846	total: 1m 44s	remaining: 378ms
# 9964:	learn: 0.6154846	total: 1m 44s	remaining: 367ms
# 9965:	learn: 0.6154846	total: 1m 44s	remaining: 357ms
# 9966:	learn: 0.6154845	total: 1m 44s	remaining: 346ms
# 9967:	learn: 0.6154845	total: 1m 44s	remaining: 336ms
# 9968:	learn: 0.6154845	total: 1m 44s	remaining: 325ms
# 9969:	learn: 0.6154845	total: 1m 44s	remaining: 315ms
# 9970:	learn: 0.6154845	total: 1m 44s	remaining: 304ms
# 9971:	learn: 0.6154845	total: 1m 44s	remaining: 294ms
# 9972:	learn: 0.6154844	total: 1m 44s	remaining: 283ms
# 9973:	learn: 0.6154838	total: 1m 44s	remaining: 273ms
# 9974:	learn: 0.6154838	total: 1m 44s	remaining: 262ms
# 9975:	learn: 0.6154837	total: 1m 44s	remaining: 252ms
# 9976:	learn: 0.6154837	total: 1m 44s	remaining: 241ms
# 9977:	learn: 0.6154837	total: 1m 44s	remaining: 231ms
# 9978:	learn: 0.6154837	total: 1m 44s	remaining: 220ms
# 9979:	learn: 0.6154837	total: 1m 44s	remaining: 210ms
# 9980:	learn: 0.6154837	total: 1m 44s	remaining: 199ms
# 9981:	learn: 0.6154836	total: 1m 44s	remaining: 189ms
# 9982:	learn: 0.6154836	total: 1m 44s	remaining: 178ms
# 9983:	learn: 0.6154836	total: 1m 44s	remaining: 168ms
# 9984:	learn: 0.6154836	total: 1m 44s	remaining: 157ms
# 9985:	learn: 0.6154836	total: 1m 44s	remaining: 147ms
# 9986:	learn: 0.6154836	total: 1m 44s	remaining: 136ms
# 9987:	learn: 0.6154836	total: 1m 44s	remaining: 126ms
# 9988:	learn: 0.6154835	total: 1m 44s	remaining: 115ms
# 9989:	learn: 0.6154835	total: 1m 44s	remaining: 105ms
# 9990:	learn: 0.6154835	total: 1m 44s	remaining: 94.5ms
# 9991:	learn: 0.6154835	total: 1m 44s	remaining: 84ms
# 9992:	learn: 0.6154835	total: 1m 44s	remaining: 73.5ms
# 9993:	learn: 0.6154835	total: 1m 44s	remaining: 63ms
# 9994:	learn: 0.6154835	total: 1m 44s	remaining: 52.5ms
# 9995:	learn: 0.6154835	total: 1m 44s	remaining: 42ms
# 9996:	learn: 0.6154834	total: 1m 44s	remaining: 31.5ms
# 9997:	learn: 0.6154834	total: 1m 44s	remaining: 21ms
# 9998:	learn: 0.6154834	total: 1m 44s	remaining: 10.5ms
# 9999:	learn: 0.6154834	total: 1m 44s	remaining: 0us
# TransformedTargetRegressor(regressor=Pipeline(steps=[('third',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('ordinal',
#                                                                                        OrdinalEncoder(),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       <catboost.core.CatBoostRegressor object at 0x7c27592c9a50>)]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
# Fit Linear Regression
lin_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(handle_unknown='ignore'),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       LinearRegression())]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
print(y_train.min())
# Out:
# 0.99

# %%
# Fit AdaBoost
ada_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(handle_unknown='ignore'),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       AdaBoostRegressor(learning_rate=0.1,
#                                                                         loss='exponential',
#                                                                         n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %%
# Fit ExtraTreesBoost
extra_pipe.fit(X_train, y_train)
# Out:
# TransformedTargetRegressor(regressor=Pipeline(steps=[('first',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('imputer',
#                                                                                        SimpleImputer(strategy='most_frequent'),
#                                                                                        [0,
#                                                                                         1,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('second',
#                                                       ColumnTransformer(remainder='passthrough',
#                                                                         sparse_threshold=0.0,
#                                                                         transformers=[('one_hot',
#                                                                                        OneHotEncoder(handle_unknown='ignore'),
#                                                                                        [0,
#                                                                                         2,
#                                                                                         3,
#                                                                                         4,
#                                                                                         5])])),
#                                                      ('model',
#                                                       ExtraTreesRegressor(bootstrap=True,
#                                                                           criterion='friedman_mse',
#                                                                           n_estimators=1000))]),
#                            transformer=PowerTransformer(method='box-cox'))

# %% [markdown]
# ### 05. Model Evaluation

# %% [markdown]
# 1. R2
# 2. RMSE (Root mean squared error)

# %%
from sklearn.metrics import r2_score, mean_squared_error

# %%
def root_mean_squared_error(y_true, y_pred):
    value = mean_squared_error(y_true, y_pred)
    return np.sqrt(value)

# %%
def generate_model_score(model, data, metric_function):
    X, y = data
    y_ = model.predict(X)
    score = metric_function(y, y_)
    return score

# %%
def print_metrics(metric_name, train_score, test_score):
    print(f"Train {metric_name} = {train_score}")
    print(f"Train {metric_name} = {test_score}")
    print(f"Generalization error =  {train_score - test_score}")

    return

# %%
def test_model(model, data, metric_name, metric_function):
    train, test = data

    if isinstance(metric_name, str): # Single metric
        train_score = generate_model_score(model, train, metric_function)
        test_score = generate_model_score(model, test, metric_function)
        print_metrics(metric_name, train_score, test_score)

    else: # Multiple metrics
        for name, function in zip(metric_name, metric_function):
            train_score = generate_model_score(model, train, function)
            test_score = generate_model_score(model, test, function)
            print_metrics(name, train_score, test_score)

    return

# %%
# Name and function for metrics
metric_name = ["R2", "RMSE"]
metric_function = [r2_score, root_mean_squared_error]

# %%
# Create data variable
data_ = [
    [X_train, y_train],
    [X_test, y_test]
]

# %%
# Test CatBoost
test_model(cat_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.3185173575480127
# Train R2 = 0.3385633904094184
# Generalization error =  -0.020046032861405716
# Train RMSE = 360.83300266509104
# Train RMSE = 379.66260058237395
# Generalization error =  -18.82959791728291

# %%
# Test LR
test_model(lin_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.07176064238099022
# Train R2 = 0.06236284299418238
# Generalization error =  0.009397799386807848
# Train RMSE = 421.12288447701536
# Train RMSE = 452.03400700575924
# Generalization error =  -30.911122528743874

# %%
# Test AdaBoost
test_model(ada_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = -0.9592989609713871
# Train R2 = -0.7551093235011539
# Generalization error =  -0.20418963747023322
# Train RMSE = 611.827800903369
# Train RMSE = 618.451703968841
# Generalization error =  -6.62390306547195

# %%
# Test ExtraTrees
test_model(extra_pipe, data_, metric_name, metric_function)
# Out:
# Train R2 = 0.21458064825017542
# Train R2 = 0.24093050774546065
# Generalization error =  -0.026349859495285233
# Train RMSE = 387.3732718084992
# Train RMSE = 406.71901052893566
# Generalization error =  -19.34573872043643

# %% [markdown]
# Observation: From the above result, it showed that the CatBoost pipeline seemed to perform best amonst them all, closely followed by ExtraTrees pipeline, while the other 2 models performed quite badly.
# Also observed was that though the CatBoost performed best, its performance also needed improvement as its still not the best wish. This then brings about the need to hypothesize why the performance its not what it should be. Then based on this hypothesis we can suggest on how we can improve our result.

# %% [markdown]
# ### 06. Model Deployment

# %% [markdown]
# As observed from the Model Evaluation phase, although the CatBoost Pipeline performed best amongst all models, its scores were still quite bad (R2 score = 0.31). A report would need to be written and a presentation be made to the executive team at Gemineye Emporium, detailing tangible reasons and hypotheses for this.
#
# Recommendations includes:
# 1. The need for more efficient information, as the dataset supplied were too scanty - filled with too much missing values. There should be a more complete dataset which would aid prediction and solve the problem better.
# 2. The need to ensure better, cleaner, more integrity-focused dataset, as this would help to fine tune the project. A large chunk of the dataset were corrupt.

# %%
# !pip install mlflow
# Out:
# Collecting mlflow
#   Downloading mlflow-2.20.2-py3-none-any.whl.metadata (30 kB)
# Collecting mlflow-skinny==2.20.2 (from mlflow)
#   Downloading mlflow_skinny-2.20.2-py3-none-any.whl.metadata (31 kB)
# Requirement already satisfied: Flask<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.0)
# Requirement already satisfied: Jinja2<4,>=2.11 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.1.5)
# Collecting alembic!=1.10.0,<2 (from mlflow)
#   Downloading alembic-1.14.1-py3-none-any.whl.metadata (7.4 kB)
# Collecting docker<8,>=4.0.0 (from mlflow)
#   Downloading docker-7.1.0-py3-none-any.whl.metadata (3.8 kB)
# Collecting graphene<4 (from mlflow)
#   Downloading graphene-3.4.3-py2.py3-none-any.whl.metadata (6.9 kB)
# Collecting gunicorn<24 (from mlflow)
#   Downloading gunicorn-23.0.0-py3-none-any.whl.metadata (4.4 kB)
# Requirement already satisfied: markdown<4,>=3.3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.7)
# Requirement already satisfied: matplotlib<4 in /usr/local/lib/python3.11/dist-packages (from mlflow) (3.10.0)
# Requirement already satisfied: numpy<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.26.4)
# Requirement already satisfied: pandas<3 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.2.2)
# Requirement already satisfied: pyarrow<19,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (17.0.0)
# Requirement already satisfied: scikit-learn<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.6.1)
# Requirement already satisfied: scipy<2 in /usr/local/lib/python3.11/dist-packages (from mlflow) (1.13.1)
# Requirement already satisfied: sqlalchemy<3,>=1.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow) (2.0.38)
# Requirement already satisfied: cachetools<6,>=5.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (5.5.1)
# Requirement already satisfied: click<9,>=7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (8.1.8)
# Requirement already satisfied: cloudpickle<4 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (3.1.1)
# Collecting databricks-sdk<1,>=0.20.0 (from mlflow-skinny==2.20.2->mlflow)
#   Downloading databricks_sdk-0.44.1-py3-none-any.whl.metadata (38 kB)
# Requirement already satisfied: gitpython<4,>=3.1.9 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (3.1.44)
# Requirement already satisfied: importlib_metadata!=4.7.0,<9,>=3.7.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (8.6.1)
# Requirement already satisfied: opentelemetry-api<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (1.16.0)
# Requirement already satisfied: opentelemetry-sdk<3,>=1.9.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (1.16.0)
# Requirement already satisfied: packaging<25 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (24.2)
# Requirement already satisfied: protobuf<6,>=3.12.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (4.25.6)
# Requirement already satisfied: pydantic<3,>=1.10.8 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (2.10.6)
# Requirement already satisfied: pyyaml<7,>=5.1 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (6.0.2)
# Requirement already satisfied: requests<3,>=2.17.3 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (2.32.3)
# Requirement already satisfied: sqlparse<1,>=0.4.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (0.5.3)
# Requirement already satisfied: typing-extensions<5,>=4.0.0 in /usr/local/lib/python3.11/dist-packages (from mlflow-skinny==2.20.2->mlflow) (4.12.2)
# Collecting Mako (from alembic!=1.10.0,<2->mlflow)
#   Downloading Mako-1.3.9-py3-none-any.whl.metadata (2.9 kB)
# Requirement already satisfied: urllib3>=1.26.0 in /usr/local/lib/python3.11/dist-packages (from docker<8,>=4.0.0->mlflow) (2.3.0)
# Requirement already satisfied: Werkzeug>=3.1 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (3.1.3)
# Requirement already satisfied: itsdangerous>=2.2 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (2.2.0)
# Requirement already satisfied: blinker>=1.9 in /usr/local/lib/python3.11/dist-packages (from Flask<4->mlflow) (1.9.0)
# Collecting graphql-core<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_core-3.2.6-py3-none-any.whl.metadata (11 kB)
# Collecting graphql-relay<3.3,>=3.1 (from graphene<4->mlflow)
#   Downloading graphql_relay-3.2.0-py3-none-any.whl.metadata (12 kB)
# Requirement already satisfied: python-dateutil<3,>=2.7.0 in /usr/local/lib/python3.11/dist-packages (from graphene<4->mlflow) (2.8.2)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from Jinja2<4,>=2.11->mlflow) (3.0.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (4.56.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (1.4.8)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (11.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib<4->mlflow) (3.2.1)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas<3->mlflow) (2025.1)
# Requirement already satisfied: joblib>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /usr/local/lib/python3.11/dist-packages (from scikit-learn<2->mlflow) (3.5.0)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.11/dist-packages (from sqlalchemy<3,>=1.4.0->mlflow) (3.1.1)
# Requirement already satisfied: google-auth~=2.0 in /usr/local/lib/python3.11/dist-packages (from databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.2->mlflow) (2.27.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /usr/local/lib/python3.11/dist-packages (from gitpython<4,>=3.1.9->mlflow-skinny==2.20.2->mlflow) (4.0.12)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata!=4.7.0,<9,>=3.7.0->mlflow-skinny==2.20.2->mlflow) (3.21.0)
# Requirement already satisfied: deprecated>=1.2.6 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.2->mlflow) (1.2.18)
# Requirement already satisfied: setuptools>=16.0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.2->mlflow) (75.1.0)
# Requirement already satisfied: opentelemetry-semantic-conventions==0.37b0 in /usr/local/lib/python3.11/dist-packages (from opentelemetry-sdk<3,>=1.9.0->mlflow-skinny==2.20.2->mlflow) (0.37b0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.2->mlflow) (0.7.0)
# Requirement already satisfied: pydantic-core==2.27.2 in /usr/local/lib/python3.11/dist-packages (from pydantic<3,>=1.10.8->mlflow-skinny==2.20.2->mlflow) (2.27.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil<3,>=2.7.0->graphene<4->mlflow) (1.17.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.2->mlflow) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.2->mlflow) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests<3,>=2.17.3->mlflow-skinny==2.20.2->mlflow) (2025.1.31)
# Requirement already satisfied: wrapt<2,>=1.10 in /usr/local/lib/python3.11/dist-packages (from deprecated>=1.2.6->opentelemetry-api<3,>=1.9.0->mlflow-skinny==2.20.2->mlflow) (1.17.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /usr/local/lib/python3.11/dist-packages (from gitdb<5,>=4.0.1->gitpython<4,>=3.1.9->mlflow-skinny==2.20.2->mlflow) (5.0.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.2->mlflow) (0.4.1)
# Requirement already satisfied: rsa<5,>=3.1.4 in /usr/local/lib/python3.11/dist-packages (from google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.2->mlflow) (4.9)
# Requirement already satisfied: pyasn1<0.7.0,>=0.4.6 in /usr/local/lib/python3.11/dist-packages (from pyasn1-modules>=0.2.1->google-auth~=2.0->databricks-sdk<1,>=0.20.0->mlflow-skinny==2.20.2->mlflow) (0.6.1)
# Downloading mlflow-2.20.2-py3-none-any.whl (28.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 28.4/28.4 MB 40.6 MB/s eta 0:00:00
# Downloading mlflow_skinny-2.20.2-py3-none-any.whl (6.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.0/6.0 MB 91.5 MB/s eta 0:00:00
# Downloading alembic-1.14.1-py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 18.1 MB/s eta 0:00:00
# Downloading docker-7.1.0-py3-none-any.whl (147 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 kB 12.7 MB/s eta 0:00:00
# Downloading graphene-3.4.3-py2.py3-none-any.whl (114 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.9/114.9 kB 10.1 MB/s eta 0:00:00
# Downloading gunicorn-23.0.0-py3-none-any.whl (85 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.0/85.0 kB 6.6 MB/s eta 0:00:00
# Downloading databricks_sdk-0.44.1-py3-none-any.whl (648 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 648.7/648.7 kB 42.9 MB/s eta 0:00:00
# Downloading graphql_core-3.2.6-py3-none-any.whl (203 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.4/203.4 kB 16.7 MB/s eta 0:00:00
# Downloading graphql_relay-3.2.0-py3-none-any.whl (16 kB)
# Downloading Mako-1.3.9-py3-none-any.whl (78 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.5/78.5 kB 6.7 MB/s eta 0:00:00
# Installing collected packages: Mako, gunicorn, graphql-core, graphql-relay, docker, alembic, graphene, databricks-sdk, mlflow-skinny, mlflow
# Successfully installed Mako-1.3.9 alembic-1.14.1 databricks-sdk-0.44.1 docker-7.1.0 graphene-3.4.3 graphql-core-3.2.6 graphql-relay-3.2.0 gunicorn-23.0.0 mlflow-2.20.2 mlflow-skinny-2.20.2

# %%
import mlflow

# %%
# Log model parameters for each pipeline
# Models and their parameters
models = {
    "CatBoost": {
        "model_type": "CatBoostRegressor",
        "loss_function": "RMSE",
        "iterations": 10000,
        "learning_rate": 0.1,
        "one_hot_max_size": 2
    },
    "LinearRegression": {
        "model_type": "LinearRegression",
        "imputation_strategy": "most_frequent",
        "encoding_method": "one_hot"
    },
    "AdaBoost": {
        "model_type": "AdaBoostRegressor",
        "loss": "exponential",
        "n_estimators": 1000,
        "learning_rate": 0.1
    },
    "ExtraTrees": {  # Added ExtraTrees
        "model_type": "ExtraTreesRegressor",
        "criterion": "friedman_mse",
        "n_estimators": 1000,
        "bootstrap": True
    }
}

# Iterate through models and log parameters in separate runs
for model_name, params in models.items():
    with mlflow.start_run(run_name=model_name):  # Start a new run for each model
        mlflow.log_params(params)
        # ... (Log metrics and artifacts for this model within the run)

# %%
# Log metrics for each model
# CatBoost:

# Calculate metrics using your model and data
from sklearn.metrics import r2_score, mean_squared_error

def root_mean_squared_error(y_true, y_pred):
    value = mean_squared_error(y_true, y_pred)
    return np.sqrt(value)

train_r2_catboost = r2_score(y_train, cat_pipe.predict(X_train))
test_r2_catboost = r2_score(y_test, cat_pipe.predict(X_test))
train_rmse_catboost = root_mean_squared_error(y_train, cat_pipe.predict(X_train))
test_rmse_catboost = root_mean_squared_error(y_test, cat_pipe.predict(X_test))

# Now log the calculated metrics
mlflow.log_metric("train_r2", train_r2_catboost)
mlflow.log_metric("test_r2", test_r2_catboost)
mlflow.log_metric("train_rmse", train_rmse_catboost)
mlflow.log_metric("test_rmse", test_rmse_catboost)

# %%
# LinearRegression:

# Calculate metrics using your model and data
from sklearn.metrics import r2_score, mean_squared_error

def root_mean_squared_error(y_true, y_pred):
    value = mean_squared_error(y_true, y_pred)
    return np.sqrt(value)

train_r2_LinearRegression = r2_score(y_train, lin_pipe.predict(X_train))
test_r2_LinearRegression = r2_score(y_test, lin_pipe.predict(X_test))
train_rmse_LinearRegression = root_mean_squared_error(y_train, lin_pipe.predict(X_train))
test_rmse_LinearRegression = root_mean_squared_error(y_test, lin_pipe.predict(X_test))

# Now log the calculated metrics
mlflow.log_metric("train_r2", train_r2_LinearRegression)
mlflow.log_metric("test_r2", test_r2_LinearRegression)
mlflow.log_metric("train_rmse", train_rmse_LinearRegression)
mlflow.log_metric("test_rmse", test_rmse_LinearRegression)

# %%
 # AdaBoost:

# Calculate metrics using your model and data
from sklearn.metrics import r2_score, mean_squared_error

def root_mean_squared_error(y_true, y_pred):
    value = mean_squared_error(y_true, y_pred)
    return np.sqrt(value)

train_r2_AdaBoost = r2_score(y_train, ada_pipe.predict(X_train))
test_r2_AdaBoost = r2_score(y_test, ada_pipe.predict(X_test))
train_rmse_AdaBoost = root_mean_squared_error(y_train, ada_pipe.predict(X_train))
test_rmse_AdaBoost = root_mean_squared_error(y_test, ada_pipe.predict(X_test))

# Now log the calculated metrics
mlflow.log_metric("train_r2", train_r2_AdaBoost)
mlflow.log_metric("test_r2", test_r2_AdaBoost)
mlflow.log_metric("train_rmse", train_rmse_AdaBoost)
mlflow.log_metric("test_rmse", test_rmse_AdaBoost)

# %%
# ExtraTrees:

# Calculate metrics using your model and data
from sklearn.metrics import r2_score, mean_squared_error

def root_mean_squared_error(y_true, y_pred):
    value = mean_squared_error(y_true, y_pred)
    return np.sqrt(value)

train_r2_ExtraTrees = r2_score(y_train, extra_pipe.predict(X_train))
test_r2_ExtraTrees = r2_score(y_test, extra_pipe.predict(X_test))
train_rmse_ExtraTrees = root_mean_squared_error(y_train, extra_pipe.predict(X_train))
test_rmse_ExtraTrees = root_mean_squared_error(y_test, extra_pipe.predict(X_test))

# Now log the calculated metrics
mlflow.log_metric("train_r2", train_r2_ExtraTrees)
mlflow.log_metric("test_r2", test_r2_ExtraTrees)
mlflow.log_metric("train_rmse", train_rmse_ExtraTrees)
mlflow.log_metric("test_rmse", test_rmse_ExtraTrees)

# %%
  # Log your models as artifacts
mlflow.sklearn.log_model(cat_pipe, artifact_path="catboost_model")
mlflow.sklearn.log_model(lin_pipe, artifact_path="linear_regression_model")
mlflow.sklearn.log_model(ada_pipe, artifact_path="adaboost_model")
mlflow.sklearn.log_model(extra_pipe, artifact_path="extratrees_model")
# Out:
# 2025/02/16 19:06:59 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/16 19:07:03 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/16 19:07:07 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.
# 2025/02/16 19:07:12 WARNING mlflow.models.model: Model logged without a signature and input example. Please set `input_example` parameter when logging the model to auto infer the model signature.

# %%
# !mlflow ui
# Out:
# [2025-02-16 19:08:38 +0000] [17385] [INFO] Starting gunicorn 23.0.0
# [2025-02-16 19:08:38 +0000] [17385] [INFO] Listening at: http://127.0.0.1:5000 (17385)
# [2025-02-16 19:08:38 +0000] [17385] [INFO] Using worker: sync
# [2025-02-16 19:08:38 +0000] [17390] [INFO] Booting worker with pid: 17390
# [2025-02-16 19:08:38 +0000] [17391] [INFO] Booting worker with pid: 17391
# [2025-02-16 19:08:38 +0000] [17392] [INFO] Booting worker with pid: 17392
# [2025-02-16 19:08:38 +0000] [17393] [INFO] Booting worker with pid: 17393

# %%
import mlflow.models
import pandas as pd
import numpy as np

pip_reqs = ["scikit-learn==1.2.1", "cloudpickle==2.0.0", "pandas", "numpy"]

def get_signature(model, X_train):
    """Ensure outputs are in a structured format"""
    predictions = model.predict(X_train)

    if isinstance(predictions, np.ndarray):
        predictions = pd.DataFrame(predictions)  # Convert to DataFrame for proper schema logging

    return mlflow.models.infer_signature(X_train, predictions)

# Log CatBoost model
signature_cat = get_signature(cat_pipe, X_train)
mlflow.sklearn.log_model(cat_pipe, artifact_path="catboost_model", signature=signature_cat, pip_requirements=pip_reqs)

# Log Linear Regression model
signature_lin = get_signature(lin_pipe, X_train)
mlflow.sklearn.log_model(lin_pipe, artifact_path="linear_regression_model", signature=signature_lin, pip_requirements=pip_reqs)

# Log AdaBoost model
signature_ada = get_signature(ada_pipe, X_train)
mlflow.sklearn.log_model(ada_pipe, artifact_path="adaboost_model", signature=signature_ada, pip_requirements=pip_reqs)

# Log Extra Trees model
signature_extra = get_signature(extra_pipe, X_train)
mlflow.sklearn.log_model(extra_pipe, artifact_path="extratrees_model", signature=signature_extra, pip_requirements=pip_reqs)
